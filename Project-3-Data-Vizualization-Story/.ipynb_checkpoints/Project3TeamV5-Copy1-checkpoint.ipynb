# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import pymongo
import pandas as pd
import json
import datetime
import spacy
from spacy import displacy
from splinter import Browser
import re
from time import sleep
import dateutil.parser
import zillow
from pprint import pprint
import sys
sys.path.append('../')
from config import zillow_api_key

# Import SQL Alchemy
from sqlalchemy import create_engine

# Import PyMySQL (Not needed if mysqlclient is installed)
import pymysql
pymysql.install_as_MySQLdb()

# %%
# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
# Create Database Connection
# ----------------------------------
# Establish Connection to MySQL
# engine = create_engine('mysql://root:mypassword@data-bootcamp-rutgers.cn6jzamkgcqr.us-west-2.rds.amazonaws.com:3306/surfingdb')
engine = create_engine("sqlite:///surfer.sqlite")
conn = engine.connect()

# %%
# Create both the Surfer and Board tables within the database
Base.metadata.create_all(conn)

# %%
# To push the objects made and query the server we use a Session object
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Add items to the current session
session.add(NAME)
# Add items to the current session
session.add(NAME)
# Commit both objects to the database
session.commit()

# %%
nlp = spacy.load('en_core_web_md')

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Define database and collection
db = client.washingtontimes_foreclosurenotices_db
collection = db.items
collection2 = db.zillow_items

# %%
# URL of page to be scraped
# Foreclosure notices in WashingtonTimes in the City of Alexandria
url = 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty.html'
browser.visit(url)

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <base href="http://classified.washingtontimes.com/"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Foreclosure Sales FFX Cty
#   </title>
#   <meta content="" name="description"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
#   <link href="geo_templates/default/external/jquery-ui/jquery-ui.min.css?_=09944" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/default/external/css/normalize.css?_=09944" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/custom.css?_=09944" rel="stylesheet" type="text/css"/>
#   <script src="js/jquery.min.js?_=09944">
#   </script>
#   <script src="js/jquery-ui.min.js?_=09944">
#   </script>
#   <script src="js/jquery.ui.touch-punch.min.js?_=09944">
#   </script>
#   <script src="geo_templates/default/external/js/gjmain.js?_=09944">
#   </script>
#   <script src="geo_templates/default/external/js/plugins/utility.js?_=09944">
#   </script>
#   <script src="geo_templates/default/external/js/plugins/simpleCarousel.js?_=09944">
#   </script>
#   <script src="geo_templates/default/external/js/plugins/lightbox.js?_=09944">
#   </script>
#   <script src="geo_templates/default/external/js/plugins/imageFade.js?_=09944">
#   </script>
#   <script src="geo_templates/default/external/js/plugins/progress.js?_=09944">
#   </script>
#   <script src="geo_templates/default/external/js/plugins/tabs.js?_=09944">
#   </script>
#   <link href="category/358/Foreclosure-Sales-FFX-Cty/2.html" rel="next"/>
#   <script>
#    //<![CDATA[
# jQuery(function () { gjUtil.runHeartbeat = true; gjUtil.ready(); });
# jQuery(window).load(gjUtil.load);
# //]]>
#   </script>
#   <!-- Category Specific Start -->
#   <!-- Add Category/Site Meta Tags in Category Settings -->
#   <!-- Category Specific End -->
#   <!--  This loads the RSS feed  -->
#   <link href="rss_listings.php" rel="alternate" title="Newest Listing Feed" type="application/rss+xml"/>
#   <link href="//fonts.googleapis.com/css?family=Open+Sans:400,400italic,700,700italic|Montserrat:400,700|Signika:400,600,700" id="css-google-fonts" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//netdna.bootstrapcdn.com/font-awesome/4.0.3/css/font-awesome.css" id="css-font-awesome" media="all" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/bootstrap.min.css" id="css-boostrap" media="all" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/bootstrap-theme.min.css" id="css-boostrap-theme" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://twt-media.washtimes.com/static/beta/v4/css/jquery/jcarousel.css" id="css-jquery-jcarousel" media="all" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/all.css" id="css-twig-all" media="all" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/responsive.css" id="css-twig-responsive" media="all" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/retina.css" id="css-twig-retina" media="all" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/twt-defaults.css" id="css-twt" media="all" rel="stylesheet" type="text/css"/>
#   <link href="geo_templates/my_templates/external/css/twt.css" id="css-twt" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if IE]>
# <link id="css-twig-ie" rel="stylesheet" type="text/css" href="http://twt-media.washtimes.com/static/beta/v4/css/ie.css" media="all" />
# <![endif]-->
#   <!--[if lt IE 9]>
# <script type="text/javascript" src="//cdn.jsdelivr.net/html5shiv/3.7.0/html5shiv.js"></script>
# <script type="text/javascript" src="http://twt-media.washtimes.com/static/beta/v4/js/respond.custom.min.js"></script>
# <![endif]-->
#   <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script src="//d5k1a84rm5hwo.cloudfront.net/partnerapi.js" type="text/javascript">
#   </script>
#   <script src="http://twt-static.washtimes.com/v4/js/bootstrap.min.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    @media all and (max-width: 500px) {
#   .jcarousel-wrapper {
#     display: none !important;
#   }
# }
#   </style>
#   <script src="js/modernizr-2.6.2.min.js">
#   </script>
#   <script>
#    Modernizr.load({ test: Modernizr.mq('only all'),nope:'geo_templates/default/external/css/old_ie.css'});
#   </script>
#  </head>
#  <body>
#   <div id="wrapper">
#    <header class="hidden-xs" id="top-bar">
#     <div class="top-bar-inner container">
#      <div class="row">
#       <div class="dom-move widgets hidden-xs" data-media="desktop" data-target="widgets">
#        <div class="dom-move-contents">
#         <div class="weather col-sm-15 col-lg-7">
#         </div>
#         <div class="stocks col-sm-15 col-lg-8 popover-content">
#         </div>
#         <nav class="utility-nav col-sm-15 col-lg-10" role="navigation">
#          <ul class="micro-menu">
#          </ul>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <header id="masthead">
#     <div class="masthead-inner container">
#      <div class="row">
#       <div class="col-sm-15 col-lg-8" id="twt-logo">
#        <a href="/" title="The Washington Times | Home">
#         <img alt="Logo: The Washington Times" src="http://media.washtimes.com/static/beta/v4/images/logo-twt.svg"/>
#        </a>
#       </div>
#       <div class="col-sm-15 col-lg-5 col-lg-push-17 hidden-xs" id="social-media-preferences">
#        <div class="dom-move social" data-media="desktop" data-target="social">
#         <div class="dom-move-contents hidden-xs hidden-sm">
#          <span class="lbl">
#           Connect with us:
#          </span>
#          <ul>
#           <li class="facebook">
#            <a href="http://www.facebook.com/pages/WashingtonTimescom/35994014410?sk=wall" target="_blank" title="Facebook">
#            </a>
#           </li>
#           <li class="twitter">
#            <a href="http://www.twitter.com/washtimes" target="_blank" title="Twitter">
#            </a>
#           </li>
#           <li class="gplus">
#            <a href="http://google.com/" target="_blank" title="Google+">
#            </a>
#           </li>
#           <li class="rss">
#            <a href="feeds/" target="_blank" title="RSS Feed">
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="dom-move preferences" data-media="desktop" data-target="preferences">
#         <div class="dom-move-contents hidden-xs hidden-sm">
#          <ul>
#           <li class="user">
#            <fieldset>
#             <legend class="sr-only">
#              User Profile
#             </legend>
#             <a class="pseudo-menu-toggle" href="javascript:void(0);" title="Manage your profile">
#              <i class="fa fa-user fa-2x">
#              </i>
#              <span class="lbl">
#               Manage your profile
#              </span>
#             </a>
#             <div class="user-dropdown">
#              <div class="anon">
#               <a class="btn btn-sm btn-red gigya_login" href="register.php">
#                Register
#               </a>
#               <a class="btn btn-sm btn-red gigya_register" href="index.php?a=10">
#                Login
#               </a>
#              </div>
#             </div>
#            </fieldset>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div class="col-sm-30 col-lg-17 col-lg-pull-5" id="main-nav-container">
#        <nav class="navbar" id="main-nav" role="navigation">
#         <div class="navbar-header">
#          <button class="navbar-toggle" data-target="#main-nav-navbar" data-toggle="collapse" role="button" title="Toggle Navigation" type="button">
#           <span class="sr-only">
#            Toggle navigation
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#           <span class="icon-bar">
#           </span>
#          </button>
#         </div>
#         <div class="navbar-collapse collapse desktop" id="main-nav-navbar">
#          <ul class="menu nav navbar-nav" role="group">
#           <li role="presentation">
#            <a href="/" role="menuitem" title="Home">
#             Home
#            </a>
#           </li>
#           <li class="dropdown" role="presentation">
#            <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="http://www.washingtontimes.com/news/" id="main-nav-drop1" role="menuitem" title="News">
#             News
#            </a>
#            <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/politics/" role="menuitem" title="Politics">
#               Politics
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/national/" role="menuitem" title="National">
#               National
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/world/" role="menuitem" title="World">
#               World
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/security/" role="menuitem" title="Security">
#               Security
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/business-economy/" role="menuitem" title="Business &amp; Economy">
#               Business &amp; Economy
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/local/" role="menuitem" title="D.C. Local">
#               D.C. Local
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/specials/faith-and-family/" role="menuitem" title="Faith &amp; Family">
#               Faith &amp; Family
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/inside-politics/" role="menuitem" title="Inside Politics">
#               Inside Politics
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/inside-the-beltway/" role="menuitem" title="Inside the Beltway">
#               Inside the Beltway
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/inside-the-ring/" role="menuitem" title="Inside the Ring">
#               Inside the Ring
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/culture/technology/" role="menuitem" title="Technology">
#               Technology
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/culture/entertainment/" role="menuitem" title="Entertainment">
#               Entertainment
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/inside-china/" role="menuitem" title="Inside China">
#               Inside China
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/accountability/" role="menuitem" title="Accountability">
#               Accountability
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/specials/" role="menuitem" title="Special Reports">
#               Special Reports
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/communities/" role="menuitem" title="Communities">
#               Communities
#              </a>
#              <ul aria-labelledby="main-nav-drop-sub" class="dropdown-menu" id="main-nav-menu-sub" role="menu">
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/tom-delays-getting-it-right/" role="menuitem" title="Delay's Getting it right">
#                 Delay's Getting it right
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/issues-insights-istook/" role="menuitem" title="Issues, Insights &amp; Istook">
#                 Issues, Insights &amp; Istook
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/tea-time-with-judson-phillips/" role="menuitem" title="Phillip's Tea Time">
#                 Phillip's Tea Time
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/christine-odonnell-unplugged/" role="menuitem" title="Christine O'Donnell Unplugged">
#                 Christine O'Donnell Unplugged
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/rusty-humphries-rebellion/" role="menuitem" title="Rusty Humphries Rebellion ">
#                 Rusty Humphries Rebellion
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/on-the-money/" role="menuitem" title="Ortel's On the Money">
#                 Ortel's On the Money
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/midwest-conservative/" role="menuitem" title="Deace's Midwestern Conservative">
#                 Deace's Midwestern Conservative
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/jeffrey-shapiros-law-disorder/" role="menuitem" title="Jeffrey Shapiro's Law &amp; Disorder">
#                 Jeffrey Shapiro's Law &amp; Disorder
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li role="presentation">
#              <a href="http://www.legacy.com/washingtontimes/" role="menuitem" title="Obituaries">
#               Obituaries
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/today/" role="menuitem" title="JUST THE HEADLINES">
#               JUST THE HEADLINES
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/multimedia/" role="menuitem" title="Media Main">
#               Media Main
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/radio/" role="menuitem" title="Radio">
#               Radio
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/multimedia/collection" role="menuitem" title="Photo Galleries">
#               Photo Galleries
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://video.washingtontimes.com/video/" role="menuitem" title="Video">
#               Video
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="dropdown" role="presentation">
#            <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="http://www.washingtontimes.com/opinion/" id="main-nav-drop2" role="menuitem" title="Opinion">
#             Opinion
#            </a>
#            <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
#             <li class="active" role="presentation">
#              <a href="http://www.washingtontimes.com/opinion/" role="menuitem" title="Opinion Main">
#               Opinion Main
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/opinion/commentary/" role="menuitem" title="Commentary">
#               Commentary
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/opinion/editorials/" role="menuitem" title="Editorials">
#               Editorials
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/opinion/letters/" role="menuitem" title="Letters">
#               Letters
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/david-keene/" role="menuitem" title="David Keene">
#               David Keene
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/news/pruden-on-politics/" role="menuitem" title="Pruden on Politics">
#               Pruden on Politics
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/ben-s-carson/" role="menuitem" title="Ben Carson">
#               Ben Carson
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/monica-crowley/" role="menuitem" title="Monica Crowley">
#               Monica Crowley
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/tammy-bruce/" role="menuitem" title="Tammy Bruce">
#               Tammy Bruce
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/cal-thomas/" role="menuitem" title="Cal Thomas">
#               Cal Thomas
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/opinion/water-cooler/" role="menuitem" title="Water Cooler">
#               Water Cooler
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/books/" role="menuitem" title="Books">
#               Books
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/cartoons/" role="menuitem" title="Cartoons">
#               Cartoons
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/communities/" role="menuitem" title="Communities">
#               Communities
#              </a>
#              <ul aria-labelledby="main-nav-drop-sub" class="dropdown-menu" id="main-nav-menu-sub" role="menu">
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/tom-delays-getting-it-right/" role="menuitem" title="Delay's Getting it right">
#                 Delay's Getting it right
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/issues-insights-istook/" role="menuitem" title="Issues, Insights &amp; Istook">
#                 Issues, Insights &amp; Istook
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/tea-time-with-judson-phillips/" role="menuitem" title="Phillip's Tea Time">
#                 Phillip's Tea Time
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/christine-odonnell-unplugged/" role="menuitem" title="Christine O'Donnell Unplugged">
#                 Christine O'Donnell Unplugged
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/rusty-humphries-rebellion/" role="menuitem" title="Rusty Humphries Rebellion ">
#                 Rusty Humphries Rebellion
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/on-the-money/" role="menuitem" title="Ortel's On the Money">
#                 Ortel's On the Money
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/midwest-conservative/" role="menuitem" title="Deace's Midwestern Conservative">
#                 Deace's Midwestern Conservative
#                </a>
#               </li>
#               <li role="presentation">
#                <a href="http://www.washingtontimes.com/communities/jeffrey-shapiros-law-disorder/" role="menuitem" title="Jeffrey Shapiro's Law &amp; Disorder">
#                 Jeffrey Shapiro's Law &amp; Disorder
#                </a>
#               </li>
#              </ul>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/ernest-istook/" role="menuitem" title="Ernest Istook">
#               Ernest Istook
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/tom-delay/" role="menuitem" title="Tom DeLay">
#               Tom DeLay
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/rusty-humphries/" role="menuitem" title="Rusty Humphries">
#               Rusty Humphries
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/staff/christine-odonnell/" role="menuitem" title="Christine O'Donnell">
#               Christine O'Donnell
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/specials/goldwater-50-years-later/" role="menuitem" title="Goldwater 50 Years Later">
#               Goldwater 50 Years Later
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="dropdown" role="presentation">
#            <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="http://www.washingtontimes.com/sports/" id="main-nav-drop3" role="menuitem" title="Sports">
#             Sports
#            </a>
#            <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/" role="menuitem" title="Sports Main">
#               Sports Main
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/football/" role="menuitem" title="Football">
#               Football
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/baseball/" role="menuitem" title="Baseball">
#               Baseball
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/basketball/" role="menuitem" title="Basketball">
#               Basketball
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/ncaa/" role="menuitem" title="NCAA">
#               NCAA
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/olympics/" role="menuitem" title="Olympics">
#               Olympics
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/tennis/" role="menuitem" title="Tennis">
#               Tennis
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/golf/" role="menuitem" title="Golf">
#               Golf
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/hockey/" role="menuitem" title="Hockey">
#               Hockey
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/soccer/" role="menuitem" title="Soccer">
#               Soccer
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/horse-racing/" role="menuitem" title="Horse Racing">
#               Horse Racing
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/sports/racing/" role="menuitem" title="NASCAR &amp; Racing">
#               NASCAR &amp; Racing
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="http://www.washingtontimes.com/specials/washington-redskins-season/" role="menuitem" title="Redskins 2014">
#               Redskins 2014
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="dropdown" role="presentation">
#            <a data-target="#" data-toggle="dropdown" href="/" id="main-nav-drop4" role="menuitem" title="Media">
#             Classifieds
#            </a>
#           </li>
#           <li class="dropdown" role="presentation">
#            <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="multimedia/" id="main-nav-drop5" role="menuitem" title="Market">
#             Market
#            </a>
#            <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
#             <li role="presentation">
#              <a href="http://classified.washingtontimes.com/" role="menuitem" title="Classifieds">
#               Classifieds
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="https://www.washingtontimes.com/advertise/" role="menuitem" title="Advertise With Us">
#               Advertise With Us
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="https://www.washingtontimes.com/puzzles/sudoku/" role="menuitem" title="Play Sudoku">
#               Play Sudoku
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="https://www.washingtontimes.com/puzzles/crossword/" role="menuitem" title="Crossword Puzzle">
#               Crossword Puzzle
#              </a>
#             </li>
#             <li role="presentation">
#              <a href="https://www.washingtontimes.com//quiz/" role="menuitem" title="Quizzes">
#               Quizzes
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li class="dropdown visible-xs" role="presentation">
#            <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="javascript:void(0);" id="main-nav-drop9" role="menuitem" title="Social Media">
#             Social Media
#            </a>
#            <ul aria-labelledby="main-nav-drop9" class="dropdown-menu" id="main-nav-menu9" role="menu">
#             <li class="dom-move social" data-media="mobile" data-target="social" role="presentation">
#              <div class="dom-move-contents">
#               <span class="lbl">
#                Connect with us:
#               </span>
#               <ul>
#                <li class="facebook">
#                 <a href="http://www.facebook.com/pages/WashingtonTimescom/35994014410?sk=wall" target="_blank" title="Facebook">
#                 </a>
#                </li>
#                <li class="twitter">
#                 <a href="http://www.twitter.com/washtimes" target="_blank" title="Twitter">
#                 </a>
#                </li>
#                <li class="gplus">
#                 <a href="http://google.com/" target="_blank" title="Google+">
#                 </a>
#                </li>
#                <li class="rss">
#                 <a href="http://www.washingtontimes.com/feeds/" target="_blank" title="RSS Feed">
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </li>
#            </ul>
#           </li>
#           <li class="dropdown visible-xs" role="presentation">
#            <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="javascript:void(0);" id="main-nav-drop10" role="menuitem" title="Widgets">
#             Widgets
#            </a>
#            <ul aria-labelledby="main-nav-drop10" class="dropdown-menu hidden-lg" id="main-nav-menu10" role="menu">
#             <li class="dom-move widgets" data-media="mobile" data-target="widgets" role="presentation">
#              <div class="dom-move-contents">
#               <div class="weather col-sm-15 col-lg-7">
#               </div>
#               <div class="stocks col-sm-15 col-lg-8 popover-content">
#               </div>
#               <nav class="utility-nav col-sm-15 col-lg-10" role="navigation">
#                <ul class="micro-menu">
#                 <li>
#                  <a class="btn btn-xs btn-primary btn-red" href="store/" title="Store">
#                   Store
#                  </a>
#                 </li>
#                 <li class="first">
#                  <a href="https://travel.washingtontimes.com/" target="_blank" title="Book Travel">
#                   Book Travel
#                  </a>
#                 </li>
#                 <li>
#                  <a href="subscribe/" title="Subscribe">
#                   Subscribe
#                  </a>
#                 </li>
#                 <li>
#                  <a href="http://www.print2webcorp.com/marketplace/washingtontimes/main/" title="Classifieds">
#                   Classifieds
#                  </a>
#                 </li>
#                 <li>
#                  <a class="Weekly Ads" href="weekly-ads/">
#                   Weekly Ads
#                  </a>
#                 </li>
#                </ul>
#               </nav>
#               <div class="search col-sm-15 col-lg-5">
#                <form action="http://www.washingtontimes.com/search/" id="frm_search">
#                 <fieldset>
#                  <legend class="sr-only">
#                   Search
#                  </legend>
#                  <label class="sr-only" for="search-keyword" title="Search Keyword">
#                   Search Keyword:
#                  </label>
#                  <input name="cx" type="hidden" value="015385541671335030271:nfb7f1nj88q"/>
#                  <input name="cof" type="hidden" value="FORID:11"/>
#                  <input name="ie" type="hidden" value="UTF-8"/>
#                  <input id="search-keyword" name="q" placeholder="Search" type="search" value=""/>
#                  <input class="btn btn-default btn-xs" name="sa" title="Search" type="submit" value="GO"/>
#                 </fieldset>
#                </form>
#                <script src="http://www.google.com/coop/cse/brand?form=cse-search-box&amp;lang=en" type="text/javascript">
#                </script>
#               </div>
#              </div>
#              <!-- //.dom-move-contents -->
#             </li>
#            </ul>
#           </li>
#           <li class="dropdown visible-xs" role="presentation">
#            <a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="javascript:void(0);" id="main-nav-drop11" role="menuitem" title="Preferences">
#             Preferences
#            </a>
#            <ul aria-labelledby="main-nav-drop11" class="dropdown-menu" id="main-nav-menu11" role="menu">
#             <li class="dom-move preferences" data-media="mobile" data-target="preferences" role="presentation">
#              <div class="dom-move-contents">
#               <ul>
#                <li class="user">
#                 <fieldset>
#                  <legend class="sr-only">
#                   User Profile
#                  </legend>
#                  <a class="pseudo-menu-toggle" href="javascript:void(0);" title="Manage your profile">
#                   <i class="fa fa-user fa-2x">
#                   </i>
#                   <span class="lbl">
#                    Manage your profile
#                   </span>
#                  </a>
#                  <div class="user-dropdown">
#                   <div class="txt-customize">
#                    <div class="anon" style="display: block;">
#                     <button class="btn btn-sm btn-red gigya_login" href="javascript:void(0);" title="Login">
#                      Login
#                     </button>
#                     <button class="btn btn-sm btn-red gigya_register" href="javascript:void(0);" title="Signup">
#                      Register
#                     </button>
#                    </div>
#                    <div class="txt-info">
#                     Login or Signup now to share stories and leave comments.
#                    </div>
#                   </div>
#                   <div class="auth" style="display: none;">
#                    <div id="id_welcome_msg">
#                    </div>
#                    <a class="gigya_edit_profile" href="#">
#                     Edit Your Profile
#                    </a>
#                    <a class="gigya_logout" href="#">
#                     Logout
#                    </a>
#                   </div>
#                  </div>
#                 </fieldset>
#                </li>
#               </ul>
#              </div>
#              <!-- //.dom-move-contents -->
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </div>
#         <!-- //.nav-collapse -->
#        </nav>
#        <!-- //#main-nav -->
#       </div>
#       <!-- //#main-nav-container -->
#      </div>
#     </div>
#    </header>
#    <!--[if lt IE 9]>
# 				<p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# 			<![endif]-->
#    <div class="container" id="main">
#     <!-- MAIN CONTENTS OF PAGE -->
#     <nav class="breadcrumb">
#      <div class="highlight">
#       Category:
#      </div>
#      <a href="index.php">
#       All Categories
#      </a>
#      <a href="category/304/Announcements.html">
#       Announcements
#      </a>
#      <div class="active">
#       Foreclosure Sales FFX Cty
#      </div>
#     </nav>
#     <br/>
#     <div id="content_column_wide">
#      <div class="search row">
#       <div class="col-md-20 col-lg-22" id="search-box">
#        <!-- FIND FORM BEGIN -->
#        <h1 class="search_title">
#         CLASSIFIEDS
#        </h1>
#        <div class="search-box-wrapper">
#         <form action="index.php" class="showcase clearfix" method="get">
#          <input name="a" type="hidden" value="19"/>
#          <input name="b[subcategories_also]" type="hidden" value="1"/>
#          <input class="keyword" name="b[search_text]" placeholder="search keywords..." type="text"/>
#          <input class="btn btn-primary" type="submit" value="Search"/>
#         </form>
#        </div>
#        <!-- FIND FORM END -->
#       </div>
#       <div class="browse_mode_buttons">
#        Sort By:
#        <a href="category/358/Foreclosure-Sales-FFX-Cty.html" style="display: none;">
#        </a>
#        <select class="browse_sort_dropdown field" name="c">
#         <option selected="selected" value="0">
#         </option>
#         <option value="1">
#          Lowest Price
#         </option>
#         <option value="2">
#          Highest Price
#         </option>
#         <option value="5">
#          Title
#         </option>
#        </select>
#        <a class="view_mode_link" href="index.php?a=5&amp;b=358&amp;c=0&amp;browse_view=grid" title="Grid">
#         <img alt="Grid" src="geo_templates/my_templates/external/images/icon_grid.png"/>
#        </a>
#        <a class="view_mode_link active" href="index.php?a=5&amp;b=358&amp;c=0&amp;browse_view=list" title="List">
#         <img alt="List" src="geo_templates/my_templates/external/images/icon_list.png"/>
#        </a>
#        <a class="view_mode_link" href="index.php?a=5&amp;b=358&amp;c=0&amp;browse_view=gallery" title="Gallery">
#         <img alt="Gallery" src="geo_templates/my_templates/external/images/icon_gallery.png"/>
#        </a>
#       </div>
#       <div class="clear">
#       </div>
#       <div class="content_box">
#        <h2 class="title">
#         Newest Classifieds in  Foreclosure Sales FFX Cty
#        </h2>
#        <!-- CLICK PERFORMANCE ADSENSE START -->
#        <div style="width:100%;background-color:#e9f3ff;border:3px #eaeaea solid;margin-top:10px;margin-bottom:10px;">
#         <div style="margin-top:10px;margin-bottom:10px;">
#          <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#          </script>
#          <!-- Classifieds_Search_Top -->
#          <ins class="adsbygoogle" data-ad-client="ca-pub-9012993659965611" data-ad-slot="3983723118" data-ad-slot-name="Classifieds_Search_Top" data-max-num-ads="1" data-override-format="true" data-partner="Click Performance Group" data-partner-url="www.click-performance.com" style="display:inline-block;width:100%;height:90px;max-width:970px;">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#        </div>
#        <!-- CLICK PERFORMANCE ADSENSE END -->
#        <script>
#         var ipdb = 'http://api.ipinfodb.com/v3/ip-city?key=570badb9f2d4532185c2a763075429bc285d207467786dd9b3147fc5724d600c&ip=161.253.2.247&format=json&callback=?';
#         var juju = '/proxy.php?mimeType=application/xml&url=http%3A%2F%2Fapi.juju.com%2Fjobs%3Fpartnerid%3D06d6ba7ac8e8122dd83fefe95dc2641d%26k%3DForeclosure%2BSales%2BFFX%2BCty%26useragent%3Dpython-requests%252F2.19.1%26ipaddress%3D161.253.2.247%26jpp%3D30';
#
#         var parent_category_id = '';
#         var ebay ='http://svcs.ebay.com/services/search/FindingService/v1?OPERATION-NAME=findItemsAdvanced&SERVICE-VERSION=1.0.0&SECURITY-APPNAME=TheWashi-8216-4642-a94e-befab72987b4&RESPONSE-DATA-FORMAT=JSON&REST-PAYLOAD&keywords=Foreclosure+Sales+FFX+Cty&paginationInput.entriesPerPage=30&affiliate.networkId=9&affiliate.trackingId=5337692228&affiliate.customId=twt-classifieds&callback=?';
#
#         if (parent_category_id == 'top') {
#         }
#         else if (parent_category_id != '') {
#           ebay += '&categoryId=' + parent_category_id;
#         }
#
#
#
#
#             $.getJSON(
#                 ebay,
#                 function(data) {
#                     var items = data.findItemsAdvancedResponse[0].searchResult[0].item;
#                     var listing;
#                     for (var i = items.length - 1; i >= 0; i--) {
#
#                         listing = '<div class="ebay-listing clearfix">';
#                         listing +='<div class="image">';
#                         listing += '<a href=\"';
#                         listing += items[i].viewItemURL[0];
#                         listing += '\">'
#                         listing += '<img src=\"' +items[i].galleryURL[0] + '\" /></div>';
#                         listing += items[i].title[0];
#                         listing += '</a>';
#                         listing += '</div>';
#                         $(listing).appendTo('.ebay-listings');
#                     }
#
#                 }
#             );
#        </script>
#        <div class="listing_set list">
#         <article class="listing clearfix browsing_result_table_body_even">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html">
#            <img alt="00024981" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=94981" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html">
#             00024981
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html">
#            TRUSTEE'S SALE OF    9505 Yawl Court    Burke, VA 22015         In execution of a Deed of Trust in the original principal amount of $628,408.00, dated November 30, 2017, recorded among the land records of the Circuit Court for Fairfax County on December 1, 2017, as Instrument Number 2017074125.020, in Deed Book 25264, at Page 1550, the undersigned appointed Substitute Trustee will offer...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_odd">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95239/00026231.html">
#            <img alt="00026231" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95239/00026231.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95239/00026231.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=95239" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95239/00026231.html">
#             00026231
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95239/00026231.html">
#            TRUSTEE’S SALE OF 473 VIRGINIA AVENUE, HERNDON, VA 20170.   In execution of a certain Deed of Trust dated February 21, 2006, in the original principal amount of $319,500.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18248 at Page 1605 as Instrument No. 2006006998.007 . The undersigned Substitute Trustee will offer for sale at public auction...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_even">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94985/00026009.html">
#            <img alt="00026009" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94985/00026009.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94985/00026009.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=94985" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94985/00026009.html">
#             00026009
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94985/00026009.html">
#            TRUSTEE’S SALE OF  1312 YELLOW TAVERN COURT, HERNDON, VA 20170.   In execution of a certain Deed of Trust dated November 15, 2005, in the original principal amount of $300,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 17973 at Page 0145 as Instrument No. 2005048032.015 . The undersigned Substitute Trustee will offer for sale at public...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_odd">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95241/00026232.html">
#            <img alt="00026232" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95241/00026232.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95241/00026232.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=95241" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95241/00026232.html">
#             00026232
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95241/00026232.html">
#            TRUSTEE’S SALE OF 3947 EL SONETA PLACE APT 14, ALEXANDRIA, VA 22309.   In execution of a certain Deed of Trust dated May 23, 2014, in the original principal amount of $157,675.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 23669 at Page 0446 as Instrument No. 2014013237.016 . The undersigned Substitute Trustee will offer for sale at public...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_even">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95242/00026233.html">
#            <img alt="00026233" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95242/00026233.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95242/00026233.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=95242" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95242/00026233.html">
#             00026233
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95242/00026233.html">
#            TRUSTEE’S SALE OF 608 DEERFIELD POND COURT, GREAT FALLS, VA 22066.   In execution of a certain Deed of Trust dated May 2, 2007, in the original principal amount of $2,000,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 19311 at Page 1736 as Instrument No. 2007013175.006 . The undersigned Substitute Trustee will offer for sale at public...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_odd">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94732/00025793.html">
#            <img alt="00025793" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94732/00025793.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94732/00025793.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=94732" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94732/00025793.html">
#             00025793
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94732/00025793.html">
#            TRUSTEE’S SALE OF 9209 BRIARY LANE, FAIRFAX, VA 22031.   In execution of a certain Deed of Trust dated November 3, 2006, in the original principal amount of $520,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18909 at Page 1652 as Instrument No. 2006035110.017 . The undersigned Substitute Trustee will offer for sale at public auction in...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_even">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94478/00025542.html">
#            <img alt="00025542" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94478/00025542.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94478/00025542.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=94478" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94478/00025542.html">
#             00025542
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94478/00025542.html">
#            TRUSTEE'S SAL    504 CREEK CROSSING RD NE    VIENNA, VA 22180         In execution of the Deed of Trust in the original principal amount of $630,000.00, dated May 12, 2006, and recorded in Deed Book 18467, Page 1377 and as Instrument Number 2006016313.005 of the Fairfax County land records, the appointed Substitute Trustee will offer for sale at public auction   at the front of the Fairfax...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_odd">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94734/00025794.html">
#            <img alt="00025794" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94734/00025794.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94734/00025794.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=94734" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94734/00025794.html">
#             00025794
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94734/00025794.html">
#            TRUSTEE’S SALE OF 3510 SHARON CHAPEL ROAD, ALEXANDRIA, VA 22310-2313.   In execution of a certain Deed of Trust dated October 5, 2006, in the original principal amount of $515,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18843 at Page 0822 as Instrument No. 2006032414.003 . The undersigned Substitute Trustee will offer for sale at public...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_even">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94224/00025182.html">
#            <img alt="00025182" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94224/00025182.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94224/00025182.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=94224" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94224/00025182.html">
#             00025182
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94224/00025182.html">
#            TRUSTEE’S SALE OF 6722 QUANDER ROAD, ALEXANDRIA, VA 22307.   In execution of a certain Deed of Trust dated March 5, 2004, in the original principal amount of $90,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 15775 at Page 0747 as Instrument No. 2004009787.014 . The undersigned Substitute Trustee will offer for sale at public auction in...
#           </a>
#          </p>
#         </article>
#         <article class="listing clearfix browsing_result_table_body_odd">
#          <div style="float: right; text-align: right;">
#           <p class="price">
#            <!-- -->
#            <span class="price">
#             US
#            </span>
#           </p>
#          </div>
#          <div class="image">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94993/00025673.html">
#            <img alt="00025673" src="geo_templates/my_templates/external/images/no_photo.gif"/>
#           </a>
#           <div style="text-align:center; margin-top: 3px;">
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94993/00025673.html">
#             0
#            </a>
#            |
#            <img alt="" src="geo_templates/my_templates/external/images/icons/camera_video_sml.png"/>
#            :
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94993/00025673.html">
#             0
#            </a>
#            <!-- &nbsp;|&nbsp;
# 				<img src="geo_templates/my_templates/external/images/icons/heart_sml.png" alt="" />&nbsp;:&nbsp;<a href="index.php?a=20&amp;b=94993" class="favorites_link"><i class="fa fa-heart"></i></a>
# 				-->
#           </div>
#          </div>
#          <div class="title">
#           <h1>
#            <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94993/00025673.html">
#             00025673
#            </a>
#           </h1>
#          </div>
#          <p class="description">
#           <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94993/00025673.html">
#            TRUSTEE’S SALE OF 14801 RYDELL ROAD APT 304, CENTREVILLE, VA 20121.   In execution of a certain Deed of Trust dated February 14, 2006, in the original principal amount of $212,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18217 at Page 0268 as Instrument No. 2006005688.005. The undersigned Substitute Trustee will offer for sale at public...
#           </a>
#          </p>
#         </article>
#        </div>
#        <ul class="pagination browsing_result_page_links">
#         <li class="current">
#          1
#         </li>
#         <li>
#          <a href="category/358/Foreclosure-Sales-FFX-Cty/2.html">
#           2
#          </a>
#         </li>
#         <li>
#          <a href="category/358/Foreclosure-Sales-FFX-Cty/3.html">
#           3
#          </a>
#         </li>
#         <li>
#          <a href="category/358/Foreclosure-Sales-FFX-Cty/4.html">
#           4
#          </a>
#         </li>
#         <li>
#          <a href="category/358/Foreclosure-Sales-FFX-Cty/10.html">
#           10
#          </a>
#         </li>
#         <li>
#          <a href="category/358/Foreclosure-Sales-FFX-Cty/2.html">
#           &gt;
#          </a>
#         </li>
#        </ul>
#        <div class="clr">
#        </div>
#        <!-- CLICK PERFORMANCE ADSENSE START -->
#        <div style="width:100%;background-color:#e9f3ff;border:3px #eaeaea solid;margin-top:10px;margin-bottom:10px;">
#         <div style="margin-top:10px;margin-bottom:10px;">
#          <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#          </script>
#          <!-- Classifieds_Search_Bottom -->
#          <ins class="adsbygoogle" data-ad-client="ca-pub-9012993659965611" data-ad-slot="5320855519" data-ad-slot-name="Classifieds_Search_Bottom" data-max-num-ads="1" data-override-format="true" data-partner="Click Performance Group" data-partner-url="www.click-performance.com" style="display:inline-block;width:100%;height:250px;max-width:970px;">
#          </ins>
#          <script>
#           (adsbygoogle = window.adsbygoogle || []).push({});
#          </script>
#         </div>
#        </div>
#        <!-- CLICK PERFORMANCE ADSENSE END -->
#       </div>
#       <br/>
#      </div>
#     </div>
#     <!-- START FOOTER -->
#     <footer id="footer">
#      <div class="footer-inner">
#       <div class="ad visible-xs hidden-lg hidden-xl" data-size="300x250" id="ad-lead-mobile2">
#        <div id="div-home-mobileabsbottom_enjR">
#         <script type="text/javascript">
#          googletag.cmd.push(function() { googletag.display('div-home-mobileabsbottom_enjR'); });
#         </script>
#         <div id="google_ads_iframe_/5856/wash.times/home_8__container__" style="border: 0pt none;">
#          <iframe bold="" both="" center="" clear:="" color:="" font-size:="" font-weight:="" frameborder="0" height="50" id="google_ads_iframe_/5856/wash.times/home_8" margin:33px="" marginheight="0" marginwidth="0" name="google_ads_iframe_/5856/wash.times/home_8" padding:5px="" scrolling="no" src="javascript:&quot;&lt;html&gt;&lt;body style='background:transparent'&gt;&lt;div style=" text-align:="" width="300">
#           <a href="http://geodesicsolutions.com/" onclick="window.open(this.href); return false;" rel="nofollow" style="color: #a9a9a9; text-decoration: none;">
#            <img alt="" src="data:image/png;base64,..." style="vertical-align: -2px; width: 13px; height: 13px;"/>
#            Powered by Geodesic Solutions, LLC
#           </a>
#          </iframe>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %%
# results are returned as an iterable list
results = soup.find_all(class_="description")
results
# Out:
# [<p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html">
#  						TRUSTEE'S SALE OF    9505 Yawl Court    Burke, VA 22015         In execution of a Deed of Trust in the original principal amount of $628,408.00, dated November 30, 2017, recorded among the land records of the Circuit Court for Fairfax County on December 1, 2017, as Instrument Number 2017074125.020, in Deed Book 25264, at Page 1550, the undersigned appointed Substitute Trustee will offer...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95239/00026231.html">
#  						TRUSTEE’S SALE OF 473 VIRGINIA AVENUE, HERNDON, VA 20170.   In execution of a certain Deed of Trust dated February 21, 2006, in the original principal amount of $319,500.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18248 at Page 1605 as Instrument No. 2006006998.007 . The undersigned Substitute Trustee will offer for sale at public auction...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94985/00026009.html">
#  						TRUSTEE’S SALE OF  1312 YELLOW TAVERN COURT, HERNDON, VA 20170.   In execution of a certain Deed of Trust dated November 15, 2005, in the original principal amount of $300,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 17973 at Page 0145 as Instrument No. 2005048032.015 . The undersigned Substitute Trustee will offer for sale at public...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95241/00026232.html">
#  						TRUSTEE’S SALE OF 3947 EL SONETA PLACE APT 14, ALEXANDRIA, VA 22309.   In execution of a certain Deed of Trust dated May 23, 2014, in the original principal amount of $157,675.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 23669 at Page 0446 as Instrument No. 2014013237.016 . The undersigned Substitute Trustee will offer for sale at public...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/95242/00026233.html">
#  						TRUSTEE’S SALE OF 608 DEERFIELD POND COURT, GREAT FALLS, VA 22066.   In execution of a certain Deed of Trust dated May 2, 2007, in the original principal amount of $2,000,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 19311 at Page 1736 as Instrument No. 2007013175.006 . The undersigned Substitute Trustee will offer for sale at public...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94732/00025793.html">
#  						TRUSTEE’S SALE OF 9209 BRIARY LANE, FAIRFAX, VA 22031.   In execution of a certain Deed of Trust dated November 3, 2006, in the original principal amount of $520,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18909 at Page 1652 as Instrument No. 2006035110.017 . The undersigned Substitute Trustee will offer for sale at public auction in...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94478/00025542.html">
#  						TRUSTEE'S SAL    504 CREEK CROSSING RD NE    VIENNA, VA 22180         In execution of the Deed of Trust in the original principal amount of $630,000.00, dated May 12, 2006, and recorded in Deed Book 18467, Page 1377 and as Instrument Number 2006016313.005 of the Fairfax County land records, the appointed Substitute Trustee will offer for sale at public auction   at the front of the Fairfax...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94734/00025794.html">
#  						TRUSTEE’S SALE OF 3510 SHARON CHAPEL ROAD, ALEXANDRIA, VA 22310-2313.   In execution of a certain Deed of Trust dated October 5, 2006, in the original principal amount of $515,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18843 at Page 0822 as Instrument No. 2006032414.003 . The undersigned Substitute Trustee will offer for sale at public...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94224/00025182.html">
#  						TRUSTEE’S SALE OF 6722 QUANDER ROAD, ALEXANDRIA, VA 22307.   In execution of a certain Deed of Trust dated March 5, 2004, in the original principal amount of $90,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 15775 at Page 0747 as Instrument No. 2004009787.014 . The undersigned Substitute Trustee will offer for sale at public auction in...
#        </a>
#  </p>, <p class="description">
#  <a href="category/358/Foreclosure-Sales-FFX-Cty/listings/94993/00025673.html">
#  						TRUSTEE’S SALE OF 14801 RYDELL ROAD APT 304, CENTREVILLE, VA 20121.   In execution of a certain Deed of Trust dated February 14, 2006, in the original principal amount of $212,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18217 at Page 0268 as Instrument No. 2006005688.005. The undersigned Substitute Trustee will offer for sale at public...
#        </a>
#  </p>]

# %%
for result in results:
    print(result.a['href'])
# Out:
# category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/95239/00026231.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/94985/00026009.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/95241/00026232.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/95242/00026233.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/94732/00025793.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/94478/00025542.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/94734/00025794.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/94224/00025182.html
# category/358/Foreclosure-Sales-FFX-Cty/listings/94993/00025673.html

# %%
url = "http://classified.washingtontimes.com/" + results[0].a['href']
url
# Out:
# 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html'

# %%
response = requests.get(url)
soup2 = BeautifulSoup(response.text, 'lxml')
soup2
#results2 = soup2.find('div', class_="mapaddress").text
# Out:
# <!DOCTYPE html>
# <html class="no-js">
# <head><base href="http://classified.washingtontimes.com/"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>00024981 : Foreclosure Sales FFX Cty</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
# <link href="geo_templates/default/external/jquery-ui/jquery-ui.min.css?_=09944" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/default/external/css/normalize.css?_=09944" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/default/external/css/addon/sharing/sharing.css?_=09944" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/custom.css?_=09944" rel="stylesheet" type="text/css"/><script src="js/jquery.min.js?_=09944"></script>
# <script src="js/jquery-ui.min.js?_=09944"></script>
# <script src="js/jquery.ui.touch-punch.min.js?_=09944"></script>
# <script src="geo_templates/default/external/js/gjmain.js?_=09944"></script>
# <script src="geo_templates/default/external/js/plugins/utility.js?_=09944"></script>
# <script src="geo_templates/default/external/js/plugins/simpleCarousel.js?_=09944"></script>
# <script src="geo_templates/default/external/js/plugins/lightbox.js?_=09944"></script>
# <script src="geo_templates/default/external/js/plugins/imageFade.js?_=09944"></script>
# <script src="geo_templates/default/external/js/plugins/progress.js?_=09944"></script>
# <script src="geo_templates/default/external/js/plugins/tabs.js?_=09944"></script>
# <script src="addons/google_maps/maps.js?_=09944"></script>
# <meta content="TRUSTEE&amp;apos;S SALE OF    9505 Yawl Court    Burke, VA 22015         In execution of a Deed of Trust in the original principal amount of $628,408.00, dated November 30, 2017, recorded among the land records of the Circuit Court for Fairfax County on December 1, 2017, as Instrument Number 2017074125.020, in Deed Book 25264, at Page 1550, the undersigned appointed Substitute Trustee will offer for sale at public auction, at the   main entrance of the courthouse for the Circuit Court of Fairfax County, 4110 Chain Bridge Rd, Fairfax, VA on May 10, 2019 at 9:30 AM,   the property described in said deed of trust, located at the above address and briefly described as: LOT 64-A, SECTION TWO, LONGWOOD KNOLLS, AS THE SAME APPEARS DULY DEDICATED, PLATTED. AND RECORDED AND RESUBDIVIDED BY DEED OF RESUBDIVISION IN DEED BOOK 4702 AT PAGE 193 AMONG THE LAND RECORDS OF FAIRFAX COUNTY, VIRGINIA.         Tax ID: 0883 03 0064A.         TERMS OF SALE: ALL CASH.   A bidder&amp;rsquo;s deposit of $15,000.00 or 10% of the sale price, whichever is lower, will be required in the form of a certified or cashier&amp;rsquo;s check. Cash will not be accepted as a deposit. Settlement within fifteen (15) days of sale, otherwise Trustee may forfeit deposit. Additional terms to be announced at sale. This is a communication from a debt collector. This notice is an attempt to collect on a debt and any information obtained will be used for that purpose.         (Trustee # 587660)         Substitute Trustee:     ALG Trustee, LLC, C/O Orlans PC      PO Box 2548,     Leesburg, VA 20177,     (703) 777-7101,     website:   http://www.orlans.com         The Vendor Auction.com will be used in conjunction with this sale         Potential Bidders: For sale information, please visit www.Auction.com or call (800) 280-2832.         Towne #   5000.2126         April 3, 2019    April 10, 2019            AD#24981" property="og:description"/>
# <meta content="00024981" property="og:title"/>
# <meta content="product" property="og:type"/>
# <meta content="http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html" property="og:url"/>
# <script>
# //<![CDATA[
# (function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/all.js#xfbml=1";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));
# //]]>
# </script>
# <script>
# //<![CDATA[
# jQuery(function () { gjUtil.runHeartbeat = true; gjUtil.ready(); });
# jQuery(window).load(gjUtil.load);
# //]]>
# </script>
# <!-- Category Specific Start -->
# <!-- Add Category/Site Meta Tags in Category Settings -->
# <!-- Category Specific End -->
# <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyDOIFlZCySvpBwmQ2TOQbU01LMjbNkvf44&amp;sensor=false"></script>
# <!--  This loads the RSS feed  -->
# <link href="rss_listings.php" rel="alternate" title="Newest Listing Feed" type="application/rss+xml"/>
# <link href="//fonts.googleapis.com/css?family=Open+Sans:400,400italic,700,700italic|Montserrat:400,700|Signika:400,600,700" id="css-google-fonts" media="all" rel="stylesheet" type="text/css"/>
# <link href="//netdna.bootstrapcdn.com/font-awesome/4.0.3/css/font-awesome.css" id="css-font-awesome" media="all" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/bootstrap.min.css" id="css-boostrap" media="all" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/bootstrap-theme.min.css" id="css-boostrap-theme" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://twt-media.washtimes.com/static/beta/v4/css/jquery/jcarousel.css" id="css-jquery-jcarousel" media="all" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/all.css" id="css-twig-all" media="all" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/responsive.css" id="css-twig-responsive" media="all" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/retina.css" id="css-twig-retina" media="all" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/twt-defaults.css" id="css-twt" media="all" rel="stylesheet" type="text/css"/>
# <link href="geo_templates/my_templates/external/css/twt.css" id="css-twt" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE]>
# <link id="css-twig-ie" rel="stylesheet" type="text/css" href="http://twt-media.washtimes.com/static/beta/v4/css/ie.css" media="all" />
# <![endif]-->
# <!--[if lt IE 9]>
# <script type="text/javascript" src="//cdn.jsdelivr.net/html5shiv/3.7.0/html5shiv.js"></script>
# <script type="text/javascript" src="http://twt-media.washtimes.com/static/beta/v4/js/respond.custom.min.js"></script>
# <![endif]-->
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script src="//d5k1a84rm5hwo.cloudfront.net/partnerapi.js" type="text/javascript"></script>
# <script src="http://twt-static.washtimes.com/v4/js/bootstrap.min.js" type="text/javascript"></script>
# <style type="text/css">
# @media all and (max-width: 500px) {
#   .jcarousel-wrapper {
#     display: none !important;
#   }
# }
# </style>
# <script src="js/modernizr-2.6.2.min.js"></script>
# <script>Modernizr.load({ test: Modernizr.mq('only all'),nope:'geo_templates/default/external/css/old_ie.css'});</script>
# </head>
# <body>
# <div id="wrapper">
# <header class="hidden-xs" id="top-bar">
# <div class="top-bar-inner container">
# <div class="row">
# <div class="dom-move widgets hidden-xs" data-media="desktop" data-target="widgets">
# <div class="dom-move-contents">
# <div class="weather col-sm-15 col-lg-7">
# </div>
# <div class="stocks col-sm-15 col-lg-8 popover-content">
# </div>
# <nav class="utility-nav col-sm-15 col-lg-10" role="navigation">
# <ul class="micro-menu">
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </header>
# <header id="masthead">
# <div class="masthead-inner container">
# <div class="row">
# <div class="col-sm-15 col-lg-8" id="twt-logo"><a href="/" title="The Washington Times | Home"><img alt="Logo: The Washington Times" src="http://media.washtimes.com/static/beta/v4/images/logo-twt.svg"/></a></div>
# <div class="col-sm-15 col-lg-5 col-lg-push-17 hidden-xs" id="social-media-preferences">
# <div class="dom-move social" data-media="desktop" data-target="social">
# <div class="dom-move-contents hidden-xs hidden-sm"><span class="lbl">Connect with us:</span>
# <ul>
# <li class="facebook"><a href="http://www.facebook.com/pages/WashingtonTimescom/35994014410?sk=wall" target="_blank" title="Facebook"></a></li>
# <li class="twitter"><a href="http://www.twitter.com/washtimes" target="_blank" title="Twitter"></a></li>
# <li class="gplus"><a href="http://google.com/" target="_blank" title="Google+"></a></li>
# <li class="rss"><a href="feeds/" target="_blank" title="RSS Feed"></a></li>
# </ul>
# </div>
# </div>
# <div class="dom-move preferences" data-media="desktop" data-target="preferences">
# <div class="dom-move-contents hidden-xs hidden-sm">
# <ul>
# <li class="user"><fieldset><legend class="sr-only">User Profile</legend><a class="pseudo-menu-toggle" href="javascript:void(0);" title="Manage your profile"><i class="fa fa-user fa-2x"></i><span class="lbl">Manage your profile</span></a>
# <div class="user-dropdown">
# <div class="anon">
# <a class="btn btn-sm btn-red gigya_login" href="register.php">Register</a>
# <a class="btn btn-sm btn-red gigya_register" href="index.php?a=10">Login</a>
# </div>
# </div>
# </fieldset></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="col-sm-30 col-lg-17 col-lg-pull-5" id="main-nav-container"><nav class="navbar" id="main-nav" role="navigation">
# <div class="navbar-header"><button class="navbar-toggle" data-target="#main-nav-navbar" data-toggle="collapse" role="button" title="Toggle Navigation" type="button"><span class="sr-only">Toggle navigation</span><span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span></button></div>
# <div class="navbar-collapse collapse desktop" id="main-nav-navbar">
# <ul class="menu nav navbar-nav" role="group">
# <li role="presentation"><a href="/" role="menuitem" title="Home">Home</a></li>
# <li class="dropdown" role="presentation"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="http://www.washingtontimes.com/news/" id="main-nav-drop1" role="menuitem" title="News">News</a>
# <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
# <li role="presentation"><a href="http://www.washingtontimes.com/news/politics/" role="menuitem" title="Politics">Politics</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/national/" role="menuitem" title="National">National</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/world/" role="menuitem" title="World">World</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/security/" role="menuitem" title="Security">Security</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/business-economy/" role="menuitem" title="Business &amp; Economy">Business &amp; Economy</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/local/" role="menuitem" title="D.C. Local">D.C. Local</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/specials/faith-and-family/" role="menuitem" title="Faith &amp; Family">Faith &amp; Family</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/inside-politics/" role="menuitem" title="Inside Politics">Inside Politics</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/inside-the-beltway/" role="menuitem" title="Inside the Beltway">Inside the Beltway</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/inside-the-ring/" role="menuitem" title="Inside the Ring">Inside the Ring</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/culture/technology/" role="menuitem" title="Technology">Technology</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/culture/entertainment/" role="menuitem" title="Entertainment">Entertainment</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/inside-china/" role="menuitem" title="Inside China">Inside China</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/accountability/" role="menuitem" title="Accountability">Accountability</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/specials/" role="menuitem" title="Special Reports">Special Reports</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/" role="menuitem" title="Communities">Communities</a>
# <ul aria-labelledby="main-nav-drop-sub" class="dropdown-menu" id="main-nav-menu-sub" role="menu">
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/tom-delays-getting-it-right/" role="menuitem" title="Delay's Getting it right">Delay's Getting it right</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/issues-insights-istook/" role="menuitem" title="Issues, Insights &amp; Istook">Issues, Insights &amp; Istook</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/tea-time-with-judson-phillips/" role="menuitem" title="Phillip's Tea Time">Phillip's Tea Time</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/christine-odonnell-unplugged/" role="menuitem" title="Christine O'Donnell Unplugged">Christine O'Donnell Unplugged</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/rusty-humphries-rebellion/" role="menuitem" title="Rusty Humphries Rebellion ">Rusty Humphries Rebellion </a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/on-the-money/" role="menuitem" title="Ortel's On the Money">Ortel's On the Money</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/midwest-conservative/" role="menuitem" title="Deace's Midwestern Conservative">Deace's Midwestern Conservative</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/jeffrey-shapiros-law-disorder/" role="menuitem" title="Jeffrey Shapiro's Law &amp; Disorder">Jeffrey Shapiro's Law &amp; Disorder</a></li>
# </ul>
# </li>
# <li role="presentation"><a href="http://www.legacy.com/washingtontimes/" role="menuitem" title="Obituaries">Obituaries</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/today/" role="menuitem" title="JUST THE HEADLINES">JUST THE HEADLINES</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/multimedia/" role="menuitem" title="Media Main">Media Main</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/radio/" role="menuitem" title="Radio">Radio</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/multimedia/collection" role="menuitem" title="Photo Galleries">Photo Galleries</a></li>
# <li role="presentation"><a href="http://video.washingtontimes.com/video/" role="menuitem" title="Video">Video</a></li>
# </ul>
# </li>
# <li class="dropdown" role="presentation"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="http://www.washingtontimes.com/opinion/" id="main-nav-drop2" role="menuitem" title="Opinion">Opinion</a>
# <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
# <li class="active" role="presentation"><a href="http://www.washingtontimes.com/opinion/" role="menuitem" title="Opinion Main">Opinion Main</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/opinion/commentary/" role="menuitem" title="Commentary">Commentary</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/opinion/editorials/" role="menuitem" title="Editorials">Editorials</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/opinion/letters/" role="menuitem" title="Letters">Letters</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/david-keene/" role="menuitem" title="David Keene">David Keene</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/news/pruden-on-politics/" role="menuitem" title="Pruden on Politics">Pruden on Politics</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/ben-s-carson/" role="menuitem" title="Ben Carson">Ben Carson</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/monica-crowley/" role="menuitem" title="Monica Crowley">Monica Crowley</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/tammy-bruce/" role="menuitem" title="Tammy Bruce">Tammy Bruce</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/cal-thomas/" role="menuitem" title="Cal Thomas">Cal Thomas</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/opinion/water-cooler/" role="menuitem" title="Water Cooler">Water Cooler</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/books/" role="menuitem" title="Books">Books</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/cartoons/" role="menuitem" title="Cartoons">Cartoons</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/" role="menuitem" title="Communities">Communities</a>
# <ul aria-labelledby="main-nav-drop-sub" class="dropdown-menu" id="main-nav-menu-sub" role="menu">
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/tom-delays-getting-it-right/" role="menuitem" title="Delay's Getting it right">Delay's Getting it right</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/issues-insights-istook/" role="menuitem" title="Issues, Insights &amp; Istook">Issues, Insights &amp; Istook</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/tea-time-with-judson-phillips/" role="menuitem" title="Phillip's Tea Time">Phillip's Tea Time</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/christine-odonnell-unplugged/" role="menuitem" title="Christine O'Donnell Unplugged">Christine O'Donnell Unplugged</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/rusty-humphries-rebellion/" role="menuitem" title="Rusty Humphries Rebellion ">Rusty Humphries Rebellion </a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/on-the-money/" role="menuitem" title="Ortel's On the Money">Ortel's On the Money</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/midwest-conservative/" role="menuitem" title="Deace's Midwestern Conservative">Deace's Midwestern Conservative</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/communities/jeffrey-shapiros-law-disorder/" role="menuitem" title="Jeffrey Shapiro's Law &amp; Disorder">Jeffrey Shapiro's Law &amp; Disorder</a></li>
# </ul>
# </li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/ernest-istook/" role="menuitem" title="Ernest Istook">Ernest Istook</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/tom-delay/" role="menuitem" title="Tom DeLay">Tom DeLay</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/rusty-humphries/" role="menuitem" title="Rusty Humphries">Rusty Humphries</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/staff/christine-odonnell/" role="menuitem" title="Christine O'Donnell">Christine O'Donnell</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/specials/goldwater-50-years-later/" role="menuitem" title="Goldwater 50 Years Later">Goldwater 50 Years Later</a></li>
# </ul>
# </li>
# <li class="dropdown" role="presentation"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="http://www.washingtontimes.com/sports/" id="main-nav-drop3" role="menuitem" title="Sports">Sports</a>
# <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/" role="menuitem" title="Sports Main">Sports Main</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/football/" role="menuitem" title="Football">Football</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/baseball/" role="menuitem" title="Baseball">Baseball</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/basketball/" role="menuitem" title="Basketball">Basketball</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/ncaa/" role="menuitem" title="NCAA">NCAA</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/olympics/" role="menuitem" title="Olympics">Olympics</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/tennis/" role="menuitem" title="Tennis">Tennis</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/golf/" role="menuitem" title="Golf">Golf</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/hockey/" role="menuitem" title="Hockey">Hockey</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/soccer/" role="menuitem" title="Soccer">Soccer</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/horse-racing/" role="menuitem" title="Horse Racing">Horse Racing</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/sports/racing/" role="menuitem" title="NASCAR &amp; Racing">NASCAR &amp; Racing</a></li>
# <li role="presentation"><a href="http://www.washingtontimes.com/specials/washington-redskins-season/" role="menuitem" title="Redskins 2014">Redskins 2014</a></li>
# </ul>
# </li>
# <li class="dropdown" role="presentation"><a data-target="#" data-toggle="dropdown" href="/" id="main-nav-drop4" role="menuitem" title="Media">Classifieds</a>
# </li>
# <li class="dropdown" role="presentation"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="multimedia/" id="main-nav-drop5" role="menuitem" title="Market">Market</a>
# <ul aria-labelledby="main-nav-drop" class="dropdown-menu" id="main-nav-menu" role="menu">
# <li role="presentation"><a href="http://classified.washingtontimes.com/" role="menuitem" title="Classifieds">Classifieds</a></li>
# <li role="presentation"><a href="https://www.washingtontimes.com/advertise/" role="menuitem" title="Advertise With Us">Advertise With Us</a></li>
# <li role="presentation"><a href="https://www.washingtontimes.com/puzzles/sudoku/" role="menuitem" title="Play Sudoku">Play Sudoku</a></li>
# <li role="presentation"><a href="https://www.washingtontimes.com/puzzles/crossword/" role="menuitem" title="Crossword Puzzle">Crossword Puzzle</a></li>
# <li role="presentation"><a href="https://www.washingtontimes.com//quiz/" role="menuitem" title="Quizzes">Quizzes</a></li>
# </ul>
# </li>
# <li class="dropdown visible-xs" role="presentation"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="javascript:void(0);" id="main-nav-drop9" role="menuitem" title="Social Media">Social Media</a>
# <ul aria-labelledby="main-nav-drop9" class="dropdown-menu" id="main-nav-menu9" role="menu">
# <li class="dom-move social" data-media="mobile" data-target="social" role="presentation">
# <div class="dom-move-contents"><span class="lbl">Connect with us:</span>
# <ul>
# <li class="facebook"><a href="http://www.facebook.com/pages/WashingtonTimescom/35994014410?sk=wall" target="_blank" title="Facebook"></a></li>
# <li class="twitter"><a href="http://www.twitter.com/washtimes" target="_blank" title="Twitter"></a></li>
# <li class="gplus"><a href="http://google.com/" target="_blank" title="Google+"></a></li>
# <li class="rss"><a href="http://www.washingtontimes.com/feeds/" target="_blank" title="RSS Feed"></a></li>
# </ul>
# </div>
# </li>
# </ul>
# </li>
# <li class="dropdown visible-xs" role="presentation"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="javascript:void(0);" id="main-nav-drop10" role="menuitem" title="Widgets">Widgets</a>
# <ul aria-labelledby="main-nav-drop10" class="dropdown-menu hidden-lg" id="main-nav-menu10" role="menu">
# <li class="dom-move widgets" data-media="mobile" data-target="widgets" role="presentation">
# <div class="dom-move-contents">
# <div class="weather col-sm-15 col-lg-7">
# </div>
# <div class="stocks col-sm-15 col-lg-8 popover-content">
# </div>
# <nav class="utility-nav col-sm-15 col-lg-10" role="navigation">
# <ul class="micro-menu">
# <li><a class="btn btn-xs btn-primary btn-red" href="store/" title="Store">Store</a></li>
# <li class="first"><a href="https://travel.washingtontimes.com/" target="_blank" title="Book Travel">Book Travel</a></li>
# <li><a href="subscribe/" title="Subscribe">Subscribe</a></li>
# <li><a href="http://www.print2webcorp.com/marketplace/washingtontimes/main/" title="Classifieds">Classifieds</a></li>
# <li><a class="Weekly Ads" href="weekly-ads/">Weekly Ads</a></li>
# </ul>
# </nav>
# <div class="search col-sm-15 col-lg-5"><form action="http://www.washingtontimes.com/search/" id="frm_search"><fieldset><legend class="sr-only">Search</legend><label class="sr-only" for="search-keyword" title="Search Keyword">Search Keyword:</label><input name="cx" type="hidden" value="015385541671335030271:nfb7f1nj88q"/><input name="cof" type="hidden" value="FORID:11"/><input name="ie" type="hidden" value="UTF-8"/><input id="search-keyword" name="q" placeholder="Search" type="search" value=""/><input class="btn btn-default btn-xs" name="sa" title="Search" type="submit" value="GO"/></fieldset></form>
# <script src="http://www.google.com/coop/cse/brand?form=cse-search-box&amp;lang=en" type="text/javascript"></script>
# </div>
# </div>
# <!-- //.dom-move-contents --></li>
# </ul>
# </li>
# <li class="dropdown visible-xs" role="presentation"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="javascript:void(0);" id="main-nav-drop11" role="menuitem" title="Preferences">Preferences</a>
# <ul aria-labelledby="main-nav-drop11" class="dropdown-menu" id="main-nav-menu11" role="menu">
# <li class="dom-move preferences" data-media="mobile" data-target="preferences" role="presentation">
# <div class="dom-move-contents">
# <ul>
# <li class="user"><fieldset><legend class="sr-only">User Profile</legend><a class="pseudo-menu-toggle" href="javascript:void(0);" title="Manage your profile"><i class="fa fa-user fa-2x"></i><span class="lbl">Manage your profile</span></a>
# <div class="user-dropdown">
# <div class="txt-customize">
# <div class="anon" style="display: block;"><button class="btn btn-sm btn-red gigya_login" href="javascript:void(0);" title="Login">Login</button><button class="btn btn-sm btn-red gigya_register" href="javascript:void(0);" title="Signup">Register</button></div>
# <div class="txt-info">Login or Signup now to share stories and leave comments.</div>
# </div>
# <div class="auth" style="display: none;">
# <div id="id_welcome_msg"></div>
# <a class="gigya_edit_profile" href="#">Edit Your Profile</a>     <a class="gigya_logout" href="#">Logout</a></div>
# </div>
# </fieldset></li>
# </ul>
# </div>
# <!-- //.dom-move-contents --></li>
# </ul>
# </li>
# </ul>
# </div>
# <!-- //.nav-collapse --></nav><!-- //#main-nav --></div>
# <!-- //#main-nav-container --></div>
# </div>
# </header>
# <!--[if lt IE 9]>
#         <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
#       <![endif]-->
# <div class="container" id="main">
# <div class="search row">
# <div class="col-md-20 col-lg-22" id="search-box">
# <!-- FIND FORM BEGIN -->
# <h1 class="search_title">CLASSIFIEDS</h1>
# <div class="search-box-wrapper">
# <form action="index.php" class="showcase clearfix" method="get">
# <input name="a" type="hidden" value="19"/>
# <input name="b[subcategories_also]" type="hidden" value="1"/>
# <input class="keyword" name="b[search_text]" placeholder="search keywords..." type="text"/>
# <input class="btn btn-primary" type="submit" value="Search Now"/>
# </form>
# </div>
# <!-- FIND FORM END -->
# </div>
# <div class="col-md-10 col-lg-8" id="place-ad">
# <a class="btn btn-primary" href="">Place an Ad for Free</a>
# </div>
# </div>
# <div class="row">
# <nav class="listing-prev-next-links">
# <a class="button previous_ad_link" href="category/358/Foreclosure-Sales-FFX-Cty/listings/94486/00025549.html">&lt;&lt; Previous</a>
# <a class="button next_ad_link" href="category/358/Foreclosure-Sales-FFX-Cty/listings/94486/00025549.html">Next &gt;&gt;</a>
# </nav>
# <div class="clearfix">
# <nav class="breadcrumb">
# <div class="highlight">Category: </div>
# <a href="index.php">Main</a>
# <a href="category/304/Announcements.html">
# 			Announcements
# 		</a>
# <a class="active" href="category/358/Foreclosure-Sales-FFX-Cty.html">
# 			Foreclosure Sales FFX Cty
# 		</a>
# </nav>
# </div>
# <div class="action_buttons" style="display: inline;">
# </div>
# <div class="listing-details col-md-21">
# <h1 class="listing_title">
#     00024981 —
#   </h1>
# <!-- MAIN CENTER COLUMN -->
# <div class="social-buttons">
# <a href="index.php?a=ap&amp;addon=sharing&amp;page=main&amp;share=94981" style="vertical-align:top;"><img alt="" id="share_button" src="geo_templates/default/external/images/addon/sharing/icon_share.png"/></a>
# <div id="share_popup" style="display: none; border: 5px solid #CCCCCC; z-index: 50; width: 270px; background-color: #F7F7F7; position: absolute; font-size: 10pt; padding: 0px;">
# <h1 class="title">Share This<span class="share_clickToClose" onclick="doShareClose();">[X]</span></h1>
# <div class="sharing_popup_list_container" id="share_lists">
# <ul class="sharing_method_list">
# <li style="margin: 2px 0px;"><a href="http://twitter.com/share?url=http%3A%2F%2Fclassified.washingtontimes.com%2Fcategory%2F358%2FForeclosure-Sales-FFX-Cty%2Flistings%2F94981%2F00024981.html" onclick="window.open(this.href); return false;"><img alt="" src="geo_templates/default/external/images/addon/sharing/icon_twitter.png" style="vertical-align: text-bottom; width: 16px; height: 16px;"/></a>
# <a href="http://twitter.com/share?url=http%3A%2F%2Fclassified.washingtontimes.com%2Fcategory%2F358%2FForeclosure-Sales-FFX-Cty%2Flistings%2F94981%2F00024981.html" onclick="window.open(this.href); return false;">twitter</a></li>
# </ul>
# <ul class="sharing_method_list">
# <li style="margin: 2px 0px;"><a href="http://facebook.com/sharer.php?u=http%3A%2F%2Fclassified.washingtontimes.com%2Fcategory%2F358%2FForeclosure-Sales-FFX-Cty%2Flistings%2F94981%2F00024981.html" onclick="window.open(this.href); return false;"><img alt="" src="geo_templates/default/external/images/addon/sharing/icon_facebook.png" style="vertical-align: text-bottom; width: 16px; height: 16px;"/></a>
# <a href="http://facebook.com/sharer.php?u=http%3A%2F%2Fclassified.washingtontimes.com%2Fcategory%2F358%2FForeclosure-Sales-FFX-Cty%2Flistings%2F94981%2F00024981.html" onclick="window.open(this.href); return false;">facebook</a></li>
# </ul>
# </div>
# </div>
# <div id="share_close" style="display: none; position: absolute; z-index: 48;"></div>
# <script type="text/javascript">
#
# //<![CDATA[
# var doShareClose = function() {
# 	jQuery('#share_close').hide();
# 	jQuery('#share_popup').hide('fast');
# }
# jQuery('#share_button').mouseover(function() {
#
# 	//get x/y coords of button
# 	pos = jQuery('#share_button').position();
#
# 	//move box into position
# 	jQuery('#share_popup').css({
# 		left : (pos.left) + 'px',
# 		top : (pos.top) + 'px'
# 	}).show('fast', function () {
# 		//once it's done fading in, show close
# 		jQuery('#share_close').show();
# 	}); //fade the box into view
#
# 	jQuery('#share_lists').show();
#
# 	//make another, transparent box around the border, for use in detecting when to close
# 	w = jQuery('#share_popup').width();
# 	h = jQuery('#share_popup').height();
# 	jQuery('#share_close').css({
# 		left : (pos.left - 15) + 'px',
# 		top : (pos.top - 15) + 'px',
# 		width : (w + 30) + 'px',
# 		height : (h + 30) + 'px'
# 	}).mouseover(doShareClose);
# });
#
# //]]>
#
# </script>
# <a class="twitter-share-button" data-count="none" href="http://twitter.com/share">Tweet</a><script src="http://platform.twitter.com/widgets.js" type="text/javascript"></script>
# <script src="https://apis.google.com/js/plusone.js" type="text/javascript"></script>
# <div class="g-plusone" data-count="false" data-href="http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html" data-size="medium" style="width: auto;"></div>
# <iframe src="http://www.facebook.com/plugins/like.php?href=http%3A%2F%2Fclassified.washingtontimes.com%2Fcategory%2F358%2FForeclosure-Sales-FFX-Cty%2Flistings%2F94981%2F00024981.html&amp;layout=button_count&amp;show_faces=false&amp;width=90&amp;action=like&amp;colorscheme=light&amp;height=21" style="border:none; overflow:hidden; width:90px; height:21px;"></iframe>
# <span class="add-to-favorites">
# <a class="favorites_link" href="index.php?a=20&amp;b=94981"><i class="fa fa-heart"></i></a>
# </span>
# </div>
# <div class="clearfix">
# <div class="posted-date">Apr 11-9:17<br/>Listing Began:</div>
# </div>
# <h1 class="title">Description</h1>
# <div class="content_box_1 clearfix">
# <h3>Seller's Comments and Description:</h3>
# <p></p><div style="background-color: #ffffff"><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">TRUSTEE'S SALE OF</span></p><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">9505 Yawl Court</span></p><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">Burke, VA 22015</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; ">In execution of a Deed of Trust in the original principal amount of $628,408.00, dated November 30, 2017, recorded among the land records of the Circuit Court for Fairfax County on December 1, 2017, as Instrument Number 2017074125.020, in Deed Book 25264, at Page 1550, the undersigned appointed Substitute Trustee will offer for sale at public auction, at the </span><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">main entrance of the courthouse for the Circuit Court of Fairfax County, 4110 Chain Bridge Rd, Fairfax, VA on May 10, 2019 at 9:30 AM,</span><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> the property described in said deed of trust, located at the above address and briefly described as: LOT 64-A, SECTION TWO, LONGWOOD KNOLLS, AS THE SAME APPEARS DULY DEDICATED, PLATTED. AND RECORDED AND RESUBDIVIDED BY DEED OF RESUBDIVISION IN DEED BOOK 4702 AT PAGE 193 AMONG THE LAND RECORDS OF FAIRFAX COUNTY, VIRGINIA.</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; ">Tax ID: 0883 03 0064A.</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">TERMS OF SALE: ALL CASH.</span><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> A bidder’s deposit of $15,000.00 or 10% of the sale price, whichever is lower, will be required in the form of a certified or cashier’s check. Cash will not be accepted as a deposit. Settlement within fifteen (15) days of sale, otherwise Trustee may forfeit deposit. Additional terms to be announced at sale. This is a communication from a debt collector. This notice is an attempt to collect on a debt and any information obtained will be used for that purpose.</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style= ...
# </div>
# <br/>
# <div class="ad">
# <!-- Classifieds_Detail_Bottom -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9012993659965611" data-ad-slot="3564920713" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
#   (adsbygoogle = window.adsbygoogle || []).push({});
#   </script>
# </div>
# <br/>
# <h1 class="title">
# </h1>
# <div class="content_box_1">
# <div class="box_pad"></div>
# </div>
# <br/>
# <br/>
# <!-- END CENTER COLUMN -->
# </div>
# <div class="col-md-9" id="second-sidebar">
# <!-- SELLER INFO BEGIN -->
# <div class="content_box_2">
# <h3 class="seller_username"><a class="display_ad_value" href="index.php?a=13&amp;b=94981"></a> </h3>
# <p class="content_section">
# <strong>Member Since: </strong><br/>
# </p>
# <p class="content_section">
#               California,
#
#
#         99600
#           </p>
# <p class="content_section cntr">
#                     Phone 2: (631) 529-9928<br/>
# </p>
# <div class="google-map clearfix"></div>
# <ul class="option_list">
# <li><a class="sellers_other_ads_link" href="other/4837/seller.html">seller's other listings</a></li>
# <li><a class="notify_seller_link" href="index.php?a=13&amp;b=94981">contact seller</a></li>
# </ul>
# </div>
# <!-- SELLER INFO END -->
# <div class="ad">
# <!-- Classifieds_Detail_Sidebar -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9012993659965611" data-ad-slot="6518387112" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
# (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </div>
# <div class="center clearfix">
# <a class="button previous_ad_link" href="category/358/Foreclosure-Sales-FFX-Cty/listings/94486/00025549.html">&lt;&lt; Previous</a>
# <a class="button next_ad_link" href="category/358/Foreclosure-Sales-FFX-Cty/listings/94486/00025549.html">Next &gt;&gt;</a>
# </div>
# </div>
# </div>
# <!-- START FOOTER -->
# <footer id="footer"><div class="footer-inner"><div class="ad visible-xs hidden-lg hidden-xl" data-size="300x250" id="ad-lead-mobile2"><div id="div-home-mobileabsbottom_enjR">
# <script type="text/javascript">
#   googletag.cmd.push(function() { googletag.display('div-home-mobileabsbottom_enjR'); });
# </script>
# <div id="google_ads_iframe_/5856/wash.times/home_8__container__" style="border: 0pt none;"><iframe bold="" both="" center="" clear:="" color:="" font-size:="" font-weight:="" frameborder="0" height="50" id="google_ads_iframe_/5856/wash.times/home_8" margin:33px="" marginheight="0" marginwidth="0" name="google_ads_iframe_/5856/wash.times/home_8" padding:5px="" scrolling="no" src="javascript:&quot;&lt;html&gt;&lt;body style='background:transparent'&gt;&lt;div style=" text-align:="" width="300"><a href="http://geodesicsolutions.com/" onclick="window.open(this.href); return false;" rel="nofollow" style="color: #a9a9a9; text-decoration: none;"><img alt="" src="data:image/png;base64,..." style="vertical-align: -2px; width: 13px; height: 13px;"/> Powered by Geodesic Solutions, LLC</a></iframe></div></div></div></div></footer></div></body></html>

# %%
results2 = soup2.find_all("div", class_="content_box_1 clearfix")
results2
# Out:
# [<div class="content_box_1 clearfix">
#  <h3>Seller's Comments and Description:</h3>
#  <p></p><div style="background-color: #ffffff"><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">TRUSTEE'S SALE OF</span></p><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">9505 Yawl Court</span></p><p style="margin: 0px; text-align: center;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">Burke, VA 22015</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; ">In execution of a Deed of Trust in the original principal amount of $628,408.00, dated November 30, 2017, recorded among the land records of the Circuit Court for Fairfax County on December 1, 2017, as Instrument Number 2017074125.020, in Deed Book 25264, at Page 1550, the undersigned appointed Substitute Trustee will offer for sale at public auction, at the </span><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">main entrance of the courthouse for the Circuit Court of Fairfax County, 4110 Chain Bridge Rd, Fairfax, VA on May 10, 2019 at 9:30 AM,</span><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> the property described in said deed of trust, located at the above address and briefly described as: LOT 64-A, SECTION TWO, LONGWOOD KNOLLS, AS THE SAME APPEARS DULY DEDICATED, PLATTED. AND RECORDED AND RESUBDIVIDED BY DEED OF RESUBDIVISION IN DEED BOOK 4702 AT PAGE 193 AMONG THE LAND RECORDS OF FAIRFAX COUNTY, VIRGINIA.</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; ">Tax ID: 0883 03 0064A.</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; font-weight: bold; ">TERMS OF SALE: ALL CASH.</span><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> A bidder’s deposit of $15,000.00 or 10% of the sale price, whichever is lower, will be required in the form of a certified or cashier’s check. Cash will not be accepted as a deposit. Settlement within fifteen (15) days of sale, otherwise Trustee may forfeit deposit. Additional terms to be announced at sale. This is a communication from a debt collector. This notice is an attempt to collect on a debt and any information obtained will be used for that purpose.</span></p><p style="margin: 0px; text-align: justify;; text-indent: 0.0px; "><span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.1666666em; text-decoration: none; "> </span></p><p style ...
#  </div>]

# %%
results2[0].text
# Out:
# "\nSeller's Comments and Description:\n TRUSTEE'S SALE OF9505 Yawl CourtBurke, VA 22015 In execution of a Deed of Trust in the original principal amount of $628,408.00, dated November 30, 2017, recorded among the land records of the Circuit Court for Fairfax County on December 1, 2017, as Instrument Number 2017074125.020, in Deed Book 25264, at Page 1550, the undersigned appointed Substitute Trustee will offer for sale at public auction, at the main entrance of the courthouse for the Circuit Court of Fairfax County, 4110 Chain Bridge Rd, Fairfax, VA on May 10, 2019 at 9:30 AM, the property described in said deed of trust, located at the above address and briefly described as: LOT 64-A, SECTION TWO, LONGWOOD KNOLLS, AS THE SAME APPEARS DULY DEDICATED, PLATTED. AND RECORDED AND RESUBDIVIDED BY DEED OF RESUBDIVISION IN DEED BOOK 4702 AT PAGE 193 AMONG THE LAND RECORDS OF FAIRFAX COUNTY, VIRGINIA. Tax ID: 0883 03 0064A. TERMS OF SALE: ALL CASH. A bidder’s deposit of $15,000.00 or 10% of the sale price, whichever is lower, will be required in the form of a certified or cashier’s check. Cash will not be accepted as a deposit. Settlement within fifteen (15) days of sale, otherwise Trustee may forfeit deposit. Additional terms to be announced at sale. This is a communication from a debt collector. This notice is an attempt to collect on a debt and any information obtained will be used for that purpose. (Trustee # 587660) Substitute Trustee: ALG Trustee, LLC, C/O Orlans PC  PO Box 2548, Leesburg, VA 20177, (703) 777-7101, website: http://www.orlans.com The Vendor Auction.com will be used in conjunction with this sale Potential Bidders: For sale information, please visit www.Auction.com or call (800) 280-2832. Towne # 5000.2126 April 3, 2019April 10, 2019  AD#24981 \n"

# %%
def original_mortgage_price(results2):
    try:
        dollar_amounts = re.findall(r"\$\d+(?:\,\d+)?", results2.text)
        numeric_dollar_amounts = [int(re.sub(",","",x[1:])) for x in dollar_amounts]
        principal_amount = max(numeric_dollar_amounts)
        
        if principal_amount < 50000:
            return -1
        else:
            return principal_amount
    except:
        principal_amount = -2
        return principal_amount

# %%
def get_listing(result):
    url = "http://classified.washingtontimes.com/" + result.a['href']
    response = requests.get(url)
    soup2 = BeautifulSoup(response.text, 'lxml')
    results2 = soup2.find_all("div", class_="content_box_1 clearfix")
    return results2

# %%
def get_address_new(result):

    r = re.sub("\n", "", result.text.lower())
    r = re.sub("\t", "", r)
    r = re.sub("'", "", r)
    test = re.sub("’", "", r)
    test = re.sub(' +', ' ', test).strip()

    _tmp_address = re.findall(r"(trustee|trustees) (.*?\d{5})", test)[0][1]
    _tmp_address = re.sub("sale","", _tmp_address)
    address = re.sub("of","", _tmp_address)
    
    return address.strip()

# %%
def get_address(results2):
    try:
        a = results2
        b = a.find_all("span")

        iter_b = iter(b)

        for i in range(len(b)):
            next_b = next(iter_b)
            print(next_b)
            
            if "trustee's sale of" in next_b.text.lower():
                print("sale of")
                result = next_b.text[18:]
                break
            
            if 'trustee' in next_b.text.lower():
                
                result = next(iter_b)
                result = result.text

                if result == ' ':
                    result = next(iter_b).text
                    break
                else:
                    break

        return result
    except:
        return "no address"
        
get_address(get_listing(results[5])[0])
# for span in b:
#     print("trustee sale" in span.lower())
# Out:
# <span style="color: #000000;font-family: 'PoynterAgateOne-Cond-Bold'; font-size: 1.0em; text-decoration: none; "> </span>
# <span style="color: #000000;font-family: 'PoynterAgateOne-Cond'; font-size: 1.0em; text-decoration: none; font-weight: bold; ">TRUSTEE’S SALE OF 9209 BRIARY LANE, FAIRFAX, VA 22031. </span>
# 'In execution of a certain Deed of Trust dated November 3, 2006, in the original principal amount of $520,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18909 at Page 1652 as Instrument No. 2006035110.017 . The undersigned Substitute Trustee will offer for sale at public auction in the front of the Circuit Court building for Fairfax County, 4110 Chain Bridge Road, Fairfax, VA on April 25, 2019, at 9:00 AM, the property described in said Deed of Trust, located at the above address, and more particularly described as follows: LOT THIRTY-SEVEN (37), SECTION TWO (2), THE BRIARS AT WESTCHESTER, AS THE SAME IS DULY DEDICATED, PLATTED AND RECORDED IN DEED BOOK 5356, PAGE 375, AMONG THE LAND RECORDS OF FAIRFAX COUNTY, VIRGINIA. TERMS OF SALE: ALL CASH. A bidder’s deposit of ten percent (10%) of the sale price or ten percent (10%) of the original principal balance of the subject Deed of Trust, whichever is lower, in the form of cash or certified funds payable to the Substitute Trustee must be present at the time of the sale. The balance of the purchase price will be due within fifteen (15) days of sale, otherwise Purchaser’s deposit may be forfeited to Trustee. Time is of the essence. If the sale is set aside for any reason, the Purchaser at the sale shall be entitled to a return of the deposit paid. The Purchaser may, if provided by the terms of the Trustee’s Memorandum of Foreclosure Sale, be entitled to a $50 cancellation fee from the Substitute Trustee, but shall have no further recourse against the Mortgagor, the Mortgagee or the Mortgagee’s attorney. Additional terms to be announced at the sale. A form copy of the Trustee’s memorandum of foreclosure sale and contract to purchase real property is available for viewing at www.bwwsales.com. This is a communication from a debt collector and any information obtained will be used for that purpose. The sale is subject to seller confirmation. Substitute Trustee: Equity Trustees, LLC, 2101 Wilson Blvd., Suite 1004, Arlington, VA 22201. For more information contact: BWW Law Group, LLC, attorneys for Equity Trustees, LLC, 6003 Executive Blvd, Suite 101, Rockville, MD 20852, 301-961-6555, website: '

# %%
def get_deposit(principal_amount, results2):
    
    nodeposit = "deposit of ten percent" in results2.text.lower()

    if nodeposit:
        return 0.1 * principal_amount
    else:
        try:
            deposit = re.findall(r"deposit of \$\d+(?:\,\d+)?", results2.text.lower())
            deposit2 = [int(re.sub(",","",x[12:])) for x in deposit]
            return deposit2[0]
        except:
            return -1

# %%
for result in results:
    listing_soup = get_listing(result)[0]
    principal_amount = original_mortgage_price(listing_soup)
    deposit = get_deposit(principal_amount, listing_soup)
    property_address = get_address_new(result)
    print(principal_amount)
    print(deposit)
    print(property_address)
    print("----")
# Out:
# 628408
# 15000
# 9505 yawl court burke, va 22015
# ----
# 319500
# 31950.0
# 473 virginia avenue, herndon, va 20170
# ----
# 300000
# 30000.0
# 1312 yellow tavern court, herndon, va 20170
# ----
# 157675
# 15767.5
# 3947 el soneta place apt 14, alexandria, va 22309
# ----
# -1
# -0.1
# 608 deerfield pond court, great falls, va 22066
# ----
# 520000
# 52000.0
# 9209 briary lane, fairfax, va 22031
# ----
# 630000
# -1
# sal 504 creek crossing rd ne vienna, va 22180
# ----
# 515000
# 51500.0
# 3510 sharon chapel road, alexandria, va 22310
# ----
# 90000
# 9000.0
# 6722 quander road, alexandria, va 22307
# ----
# 212000
# 21200.0
# 14801
# ----

# %%
# Save a sentence for processing
doc = nlp(listing_soup.text)

# # Print the entity text, starting char, ending char, and label
# for ent in doc.ents:
# #     if ent.label_ != 'DATE':
#     print(ent.text, ent.label_)
# #         _tmp = ent

def get_time(doc):
    it = iter(doc.ents)
    prev_entity = next(it)

    for i in range(len(doc.ents)):
        try:
            next_entity = next(it)
            if (prev_entity.label_ == "DATE") & (next_entity.label_ == "TIME"):
                break
            else:
                prev_entity = next_entity
        except:
            break 
    if next_entity.label_ == "TIME":
        auction_time = next_entity
    else:
        auction_time = "no time"    
    return auction_time

get_time(doc)
# Out:
# 9:00 AM

# %%
def parse_date(doc):  
    dates = []
    for ent in doc.ents:
        if ent.label_ == 'DATE':
            try:
                dates.append(dateutil.parser.parse(ent.text))
            except:
                pass
    return dates

# %%
def future_date(date_list):
#     for date in date_list:
#         if date > datetime.datetime.now():
#             return date
#     return 'no auction date'
    return max(date_list)

date_list = parse_date(doc)
auction_date = future_date(date_list)
auction_date
# Out:
# datetime.datetime(2019, 5, 9, 0, 0)

# %%
doc
# Out:
# Seller's Comments and Description:
#  TRUSTEE’S SALE OF 14801 RYDELL ROAD APT 304, CENTREVILLE, VA 20121. In execution of a certain Deed of Trust dated February 14, 2006, in the original principal amount of $212,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18217 at Page 0268 as Instrument No. 2006005688.005. The undersigned Substitute Trustee will offer for sale at public auction in the front of the Circuit Court building for Fairfax County, 4110 Chain Bridge Road, Fairfax, VA on May 9, 2019, at 9:00 AM, the property described in said Deed of Trust, located at the above address, and more particularly described as follows: CONDOMINIUM UNIT NO.: 14801 - 304, PHASE 3, MADISON RIDGE CONDOMINIUM ("CONDOMINIUM UNIT"), AND AN UNDIVIDED INTEREST IN THE COMMON ELEMENTS AND THE LIMITED COMMON ELEMENTS APPURTENANT THERETO, ESTABLISHED BY CONDOMINIUM INSTRUMENTS RECORDED JANUARY 3, 2006 IN DEED BOOK 18093 AT PAGE 1545, AND ANY AND ALL AMENDMENTS THERETO, AMONG THE LAND RECORDS OF FAIRFAX COUNTY, VIRGINIA ("LAND RECORDS"). TERMS OF SALE: ALL CASH. A bidder’s deposit of ten percent (10%) of the sale price or ten percent (10%) of the original principal balance of the subject Deed of Trust, whichever is lower, in the form of cash or certified funds payable to the Substitute Trustee must be present at the time of the sale. The balance of the purchase price will be due within fifteen (15) days of sale, otherwise Purchaser’s deposit may be forfeited to Trustee. Time is of the essence. If the sale is set aside for any reason, the Purchaser at the sale shall be entitled to a return of the deposit paid. The Purchaser may, if provided by the terms of the Trustee’s Memorandum of Foreclosure Sale, be entitled to a $50 cancellation fee from the Substitute Trustee, but shall have no further recourse against the Mortgagor, the Mortgagee or the Mortgagee’s attorney. Additional terms to be announced at the sale. A form copy of the Trustee’s memorandum of foreclosure sale and contract to purchase real property is available for viewing at www.bwwsales.com. This is a communication from a debt collector and any information obtained will be used for that purpose. The sale is subject to seller confirmation. Substitute Trustee: Equity Trustees, LLC, 2101 Wilson Blvd., Suite 1004, Arlington, VA 22201. For more information contact: BWW Law Group, LLC, attorneys for Equity Trustees, LLC, 6003 Executive Blvd, Suite 101, Rockville, MD 20852, 301-961-6555, website: www.bwwsales.com. VA-338221-1. April 3, 2019April 10, 2019AD#25673

# %%
def get_principal_date(date_list):
    try:
        return min(date_list)

    except:
        return "no principal date"


get_principal_date(date_list)
# Out:
# datetime.datetime(2006, 1, 3, 0, 0)

# %%
# def auction_location(results2):
#     re.findall(r"entrance to the .*?\d{4}", results2[0].text.lower())[0][0]
#     return auction_location

# %%
def auction_address(listings):
    deposit = re.findall(r"deposit of \$\d+(?:\,\d+)?", listings.text.lower())
    return(auction_address)

# %%
def auction_address(listings):
    re.findall(r"(trustee|trustees) (.*?\d{5})", test)[0]
    
    print(auction_address)

# %%
max(date_list)
# datetime.datetime.now()
# Out:
# datetime.datetime(2019, 5, 9, 0, 0)

# %%
spacy.info()['Location']
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    2.1.3
# Location         C:\Users\andre\AppData\Roaming\Python\Python37\site-packages\spacy
# Platform         Windows-10-10.0.17134-SP0
# Python version   3.7.0
# Models
# 'C:\\Users\\andre\\AppData\\Roaming\\Python\\Python37\\site-packages\\spacy'

# %%
#to get address

_listing = get_listing(results[2])[0]

property_address = re.findall(r"trustee .*?\d{5}", _listing.text.lower())
property_address[0]
# Out:
# 'trustee will offer for sale at public auction in the front of the circuit court building for fairfax county, 4110 chain bridge road, fairfax, va on may 2, 2019, at 9:00 am, the property described in said deed of trust, located at the above address, and more particularly described as follows: lot 37, section six (6), crestbrook, as the same appears duly dedicated, platted and recorded in deed book 5419 at page 972, among the land records of fairfax county, virginia. together with a membership in crestbrook homes association, which membership shall run with the land and automatically pass to subsequent owners of the lot herein conveyed, whether referred to specifically or not. the grantees, by accepting this conveyance, covenant and agree to abide by the protective covenants, conditions, restrictions and charges contained in the declaration recorded in deed book 4693 at page 558 and incorporated by reference in deed book 5419 at page 972, among the land records of fairfax county, virginia; take subject to all such charges and agrees that in any conveyance of the above described property, they will require their grantees to covenant to abide by such protective covenants, conditions, restrictions, and charges. terms of sale: all cash. a bidder’s deposit of ten percent (10%) of the sale price or ten percent (10%) of the original principal balance of the subject deed of trust, whichever is lower, in the form of cash or certified funds payable to the substitute trustee must be present at the time of the sale. the balance of the purchase price will be due within fifteen (15) days of sale, otherwise purchaser’s deposit may be forfeited to trustee. time is of the essence. if the sale is set aside for any reason, the purchaser at the sale shall be entitled to a return of the deposit paid. the purchaser may, if provided by the terms of the trustee’s memorandum of foreclosure sale, be entitled to a $50 cancellation fee from the substitute trustee, but shall have no further recourse against the mortgagor, the mortgagee or the mortgagee’s attorney. a form copy of the trustee’s memorandum of foreclosure sale and contract to purchase real property is available for viewing at www.bwwsales.com. additional terms, if any, to be announced at the sale. this is a communication from a debt collector and any information obtained will be used for that purpose. the sale is subject to seller confirmation. substitute trustee: equity trustees, llc, 2101 wilson blvd., suite 1004, arlington, va 22201'

# %%
auction_locations = {'520 King': '520 King Street, Alexandria, VA 22314',
                     '9311 Lee': 'T9311 Lee Ave, Manassas, VA 20110', 
                     '14735 Main': '14735 Main St, Upper Marlboro, MD 20772',
                     '4110 Chain': '4100 Chain Bridge Road, Fairfax, MD 20772',
                     '5335 Wisconsin': '5335 Wisconsin Ave NW #440, Washington, DC 20015',
                     '5301 Wisconsin': '5301 Wisconsin Ave., NW #750, Washington, DC 20015',
                     '9311 Lee':  '9311 Lee Ave, Manassas, VA 20110',
                     '9107 Judical': '9107 Judicial Center Ln, Spotsylvania, VA 22553',
                     '18 E':'18 E Market St, Leesburg, VA 20176',
                     '1300 Courthouse':  '1300 Courthouse Rd, Stafford, VA 22554',
                     '1425 N':  '1425 N Courthouse Rd #2400, Arlington, VA 22201',
                     '1722 W':  '1722 West Virginia Ave., NE, Washington, DC, 20002',
                     '200 Charles': '200 Charles St, La Plata, MD 20646',
                     '4530 Wisconsin': '4530 Wisconsin Ave NW #300, Washington, DC 20016',
                     '50 Maryland': '50 Maryland Ave, Rockville, MD 20850',             
                     'Circuit Court for Charles County':  '200 Charles St, La Plata, MD 20646',
                     'Courthouse door for the Circuit Court for Montgomery County': "345 Main Street, Montgomery, MD",
                     '9107 Judicial Center':  '9107 Judicial Center Lane, Spotsylvania, Virginia 22553',
                     '4910 Massachusetts': '4910 Massachusetts,  4910 Massachusetts Ave., NW #100, Washington, DC 20016, 202-364-0306'
                    }

def get_auction_location(soup_text, auction_locations):
    for key, value in auction_locations.items():
        if key in soup_text:
            return value
    return 'no auction location'

get_auction_location(listing_soup.text, auction_locations)
# Out:
# '1425 N Courthouse Rd #2400, Arlington, VA 22201'

# %%
def get_auction_location_new(results2):
    try:
        auction_location1 = re.findall(r"entrance to the .*?\s?\d{1,2}\:\d{2}\s?(?:AM|PM|am|pm)", results2.text.lower())
        if(len(auction_location1) > 0):
            return auction_location1
        else:
            auction_location1 = re.findall(r"entrance to the .*?\s?(?:A.M.|P.M.|a.m.|p.m.)", results2.text.lower())
            if(len(auction_location1) > 0):
                return auction_location1
            
            
        auction_location2 = re.findall(r"entrance of the .*\s?\d{1,2}\:\d{2}\s?(?:AM|PM|am|pm)", results2.text.lower())
        if(len(auction_location2) > 0):
            return auction_location2
        else:
            auction_location2 = re.findall(r"entrance of the .*?\s?(?:A.M.|P.M.|a.m.|p.m.)", results2.text.lower())
            if(len(auction_location2) > 0):
                return auction_location
            

        auction_location3 = re.findall(r"front of the .*?\s?\d{1,2}\:\d{2}\s?(?:AM|PM|am|pm)", results2.text.lower())
        if(len(auction_location3) > 0):
            return auction_location3
        else:
            auction_location3 = re.findall(r"front of the .*?\s?(?:A.M.|P.M.|a.m.|p.m.)", results2.text.lower())
            print('b')
            if(len(auction_location3) > 0):
                return auction_location3
        
        
        auction_location4 = re.findall(r"entrance to the .*?\s?\d{1,2}\:\d{2}\s?(?:AM|PM|am|pm)", results2.text.lower())
        if(len(auction_location4) > 0):
            return auction_location4
        else:
            auction_location4 = re.findall(r"entrance to the .*?\s?(?:A.M.|P.M.|a.m.|p.m.)", results2.text.lower())
            if(len(auction_location3) > 0):
                return auction_location4
            
        
        auction_location5 = re.findall(r"public auction.*?\s?\d{1,2}\:\d{2}\s?(?:AM|PM|am|pm)", results2.text.lower())
        if(len(auction_location5) > 0):
            return auction_location5
        else:
            auction_location5 = re.findall(r"public auction.*?\s?(?:A.M.|P.M.|a.m.|p.m.)", results2.text.lower())
            if(len(auction_location5) > 0):
                return auction_location5
        return []
    except:
        return -1

# %%
listing_soup.text
# Out:
# '\nSeller\'s Comments and Description:\n TRUSTEE’S SALE OF 14801 RYDELL ROAD APT 304, CENTREVILLE, VA 20121. In execution of a certain Deed of Trust dated February 14, 2006, in the original principal amount of $212,000.00 recorded in the Clerk’s Office, Circuit Court for Fairfax County, Virginia, in Book 18217 at Page 0268 as Instrument No. 2006005688.005. The undersigned Substitute Trustee will offer for sale at public auction in the front of the Circuit Court building for Fairfax County, 4110 Chain Bridge Road, Fairfax, VA on May 9, 2019, at 9:00 AM, the property described in said Deed of Trust, located at the above address, and more particularly described as follows: CONDOMINIUM UNIT NO.: 14801 - 304, PHASE 3, MADISON RIDGE CONDOMINIUM ("CONDOMINIUM UNIT"), AND AN UNDIVIDED INTEREST IN THE COMMON ELEMENTS AND THE LIMITED COMMON ELEMENTS APPURTENANT THERETO, ESTABLISHED BY CONDOMINIUM INSTRUMENTS RECORDED JANUARY 3, 2006 IN DEED BOOK 18093 AT PAGE 1545, AND ANY AND ALL AMENDMENTS THERETO, AMONG THE LAND RECORDS OF FAIRFAX COUNTY, VIRGINIA ("LAND RECORDS"). TERMS OF SALE: ALL CASH. A bidder’s deposit of ten percent (10%) of the sale price or ten percent (10%) of the original principal balance of the sub
             'M. Richard Epps': 'M. Richard Epps,,  P.C., Substitute Trustee, 605 Lynnhaven Parkway, Suite 100, Virginia Beach,VA 23452, 757-498-9600',
             'Joel L. Dahnke':  'Joel L. Dahnke, Caulkins & Bruce, P.C., 11350 Random Hills Road, Suite 700, Fairfax, Virginia 22030, Telephone (703) 273-1009'
            }

def get_law_firm(soup_text, law_firms):
    for key, value in law_firms.items():
        if key in soup_text:
            return value
    return 'no law firm'

get_law_firm(listing_soup.text, law_firms)
# Out:
# 'Samuel I. White, PC, Law Firm, http://www.siwpc.com'

# %%
city_base_list = ['http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty.html',
                 'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA.html',
                 'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty.html',
                 'http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty.html',
                 'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty.html', 
                 'http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty.html', 
                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty.html',
                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC.html',
                 'http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty.html',
                 ]

city_url_list = []

for city_url in city_base_list:
    browser.visit(city_url) 
    
    while True:
        try:
            print(browser.url)
            city_url_list.append(browser.url)
            li_tags = browser.find_by_tag('li')

            for li in li_tags:
                a_tags = li.find_by_tag('a')
                for a in a_tags:
                    if(a.text=='>'):
                        nextbtn = a

            nextbtn.click()    
        except:
            break
# Out:
# http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty.html
# http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA.html
# http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/2.html
# http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/3.html
# http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/4.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/2.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/3.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/4.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/5.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/6.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/7.html
# http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/8.html
# http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/2.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/3.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/4.html
# http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/2.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/3.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/4.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/5.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/6.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/7.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/8.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/9.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/10.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/2.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/3.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/4.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/5.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/6.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/7.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/8.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/9.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/10.html
# http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty.html

# %%
city_url_list
# Out:
# ['http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty.html',
#  'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA.html',
#  'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/2.html',
#  'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/3.html',
#  'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/4.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/2.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/3.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/4.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/5.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/6.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/7.html',
#  'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/8.html',
#  'http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty.html',
#  'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty.html',
#  'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/2.html',
#  'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/3.html',
#  'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/4.html',
#  'http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/2.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/3.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/4.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/5.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/6.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/7.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/8.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/9.html',
#  'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/10.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/2.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/3.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/4.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/5.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/6.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/7.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/8.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/9.html',
#  'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/10.html',
#  'http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty.html']

# %%
# city_url_list= ['http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty.html',
#                 'http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty/2.html',
#                 'http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty/3.html',
#                 'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA.html',
#                 'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/2.html',
#                 'http://classified.washingtontimes.com/category/405/Forclosure-Sales-VA/3.html',
#                 'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty.html',
#                 'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/2.html',
#                 'http://classified.washingtontimes.com/category/394/Foreclosure-Sales-PW-Cty/3.html',
#                 'http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty/2.html',
#                 'http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty/3.html',
#                 'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty.html',
#                 'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/2.html',
#                 'http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/3.html',
#                 'http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty.html',
#                 'http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty/2.html',
#                 'http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty/3.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/2.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/3.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/4.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/5.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/6.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/7.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/8.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/9.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/10.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/11.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/12.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/13.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/14.html',
#                 'http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/15.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/2.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/3.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/4.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/5.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/6.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/7.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/8.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/9.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/10.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/11.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/12.html',
#                 'http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/13.html',
#                 'http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty.html',
#                 'http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty/2.html',
#                 'http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty/3.html']

#taking one URL and gets that page, and then finds all the listings on it.  
#if there is a next page, then we should be doing it on line 18 - using splinter.  getting all of the next listings on the next page
#line 18 and 19 might need to be wrapped in another loop
#near 33 and 34 we want to be putting these into a mongo database

for city_url in city_url_list:#*add this to only do first there items[0:2]*
  
    # Retrieve page with the requests module
    response = requests.get(city_url)
    soup = BeautifulSoup(response.text, 'lxml')
    listings = soup.find_all(class_="description")        
    
    for foreclosure in listings[0:2]:
        url='http://classified.washingtontimes.com/'
        listing_url = url + foreclosure.a['href']     
        listing_soup = get_listing(foreclosure)[0]
        principal_amount = original_mortgage_price(listing_soup)
        deposit = get_deposit(principal_amount, listing_soup)
        
                
        doc = nlp(listing_soup.text)
        date_list = parse_date(doc)
        auction_date = future_date(date_list)
        auction_time = get_time(doc)
        principal_date = get_principal_date(date_list)
        auction_location = get_auction_location(listing_soup.text, auction_locations)
        law_firm = get_law_firm(listing_soup.text, law_firms)
    #add new items that the team comes up with to grab more data  
    
        try:
            property_address = get_address_new(foreclosure)
        except:
            property_address = "no address"      
        print(principal_amount)
        print(deposit)
        print(property_address)
        print(auction_location)
        print(city_url)
        print(listing_url)
        print(auction_date)
        print(auction_time)
        print(principal_date)
        print(auction_location)
        print(law_firm)
        print("----")
        
        #mongo database insert 
        post = {
            "city_url": city_url,
            "listing_url":  listing_url,
            "auction_location": auction_location,
            "property_address": property_address, 
            "principal_amount": principal_amount, 
            "principal_date": principal_date,
            "deposit": deposit,
            "date_of_auction": auction_date,
            "date_of_scraping": datetime.datetime.utcnow(), 
            "auction_time": str(auction_time),
            "law_firm": law_firm, 
            }
        collection.insert_one(post)
           
        sleep(3.0)
# Out:
# 151210
# 15121.0
# 31 canterbury square, apt. 201, alexandria, virginia 22304
# 520 King Street, Alexandria, VA 22314
# http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty.html
# http://classified.washingtontimes.com/category/354/Foreclosure-Sales-ALEX-Cty
# Samuel I. White, PC, Law Firm, http://www.siwpc.com
# ----
# 85800
# 8300
# improved real property 15 chinaberry lane indian head, md 20640
# 200 Charles St, La Plata, MD 20646
# http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty.html
# http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty/listings/93747/00024215.html
# 2019-03-19 00:00:00
# 1:30 PM ALL
# 2014-12-15 00:00:00
# 200 Charles St, La Plata, MD 20646
# Mid-Atlantic Auctioneers, http://www.mid-atlanticauctioneers.com
# ----
# 297110
# 31000
# improved real property 11659
# 200 Charles St, La Plata, MD 20646
# http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty.html
# http://classified.washingtontimes.com/category/393/Foreclosure-Sales-Charles-Cty/listings/94277/00024679.html
# 2019-06-27 00:00:00
# 1:30 PM ALL
# 2016-04-11 00:00:00
# 200 Charles St, La Plata, MD 20646
# Mid-Atlantic Auctioneers, http://www.mid-atlanticauctioneers.com
# ----
# 50000
# -1
# real property known as no. 8309 kittama drive clinton, md 20735
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/93739/00024612.html
# 8309-04-11 00:00:00
# 11:00 AM
# 2019-03-19 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# Alba Law Group, http://www.tidewaterauctions.com
# ----
# -1
# -1
# real property known as no. 15229
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/93741/00024614.html
# 2019-03-19 00:00:00
# 11:00 AM
# 2019-03-19 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# Alba Law Group, http://www.tidewaterauctions.com
# ----
# 62000
# 62000
# real property 8341 quill point drive bowie, md 20720
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/2.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/94009/00024868.html
# 8341-04-11 00:00:00
# 11:00 AM ALL THAT FEE SIMPLE LOT OF
# 2005-06-23 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# MDC Auctioneers, LLC, http://www.mid-atlanticauctioneers.com
# ----
# -1
# -1
# real property known as no. 2212 roslyn avenue district heights, md 20747
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/2.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/93755/00024622.html
# 2212-04-11 00:00:00
# 11:00 AM
# 2019-03-19 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# Alba Law Group, http://www.tidewaterauctions.com
# ----
# -1
# -1
# real property known as no. 7931 mandan road unit 104 greenbelt, md 20770
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/3.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/94556/00025472.html
# 7931-04-11 00:00:00
# 11:00 AM
# 2019-04-09 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# Alba Law Group, http://www.tidewaterauctions.com
# ----
# 50000
# -1
# real property known as no. 13008
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/3.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/94559/00025473.html
# 2019-04-09 00:00:00
# 11:00 AM
# 2019-04-09 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# Alba Law Group, http://www.tidewaterauctions.com
# ----
# -1
# 21000
# real property 3515 edwards street springdale, md 20774
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/4.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/95139/00025981.html
# 2019-04-23 00:00:00
# 11:00 AM ALL THAT FEE SIMPLE LOT OF
# 2008-03-03 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# MDC Auctioneers, LLC, http://www.mid-atlanticauctioneers.com
# ----
# -1
# -1
# real property known as no. 4602 cimmaron greenfields drive bowie, md 20720
# 14735 Main St, Upper Marlboro, MD 20772
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/4.html
# http://classified.washingtontimes.com/category/360/Foreclosure-Sales-PG-Cty/listings/95143/00026080.html
# 4602-04-11 00:00:00
# 11:00 AM
# 2019-04-23 00:00:00
# 14735 Main St, Upper Marlboro, MD 20772
# Alba Law Group, http://www.tidewaterauctions.com
# ----
# 980000
# 80000
# improved real property 1426 meadowsweet drive sandy spring, md 20860
# 345 Main Street, Montgomery, MD
# http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty.html
# http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty/listings/93804/00024211.html
# 2019-03-20 00:00:00
# 11:15 AM ALL
# 2006-02-23 00:00:00
# 345 Main Street, Montgomery, MD
# Mid-Atlantic Auctioneers, http://www.mid-atlanticauctioneers.com
# ----
# 123000
# 13000
# improved real property 3355 university boulevard west, apt 101 kensington, md 20895
# 345 Main Street, Montgomery, MD
# http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty.html
# http://classified.washingtontimes.com/category/359/Foreclosure-Sales-Mont-Cty/listings/94092/00024367.html
# 2019-03-27 00:00:00
# 11:15 AM ALL
# 2007-12-18 00:00:00
# 345 Main Street, Montgomery, MD
# Mid-Atlantic Auctioneers, http://www.mid-atlanticauctioneers.com
# ----
# 628408
# 15000
# 9505 yawl court burke, va 22015
# 4100 Chain Bridge Road, Fairfax, MD 20772
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/listings/94981/00024981.html
# 4702-04-11 00:00:00
# 9:30 AM
# 2017-11-30 00:00:00
# 4100 Chain Bridge Road, Fairfax, MD 20772
# ALG Trustee, LLC, http://www.orlans.com
# ----
# 319500
# 31950.0
# 473 virginia avenue, herndon, va 20170
# 4100 Chain Bridge Road, Fairfax, MD 20772
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty.html
# http://classified.washingtontimes.com/category/358/Foreclosure-Sales-FFX-Cty/listings/
# no auction location
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/8.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/listings/94365/00025210.html
# 4910-04-11 00:00:00
# 11:47 AM
# 2005-10-06 00:00:00
# no auction location
# Alex Cooper Auctioneers, http://www.alexcooper.com
# ----
# -1
# -1
# foreclosure   real property 5111 13th st., nw washington, dc 20011
# no auction location
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/9.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/listings/94139/00025136.html
# 4910-04-11 00:00:00
# 11:14 AM
# 2006-11-14 00:00:00
# no auction location
# Alex Cooper Auctioneers, http://www.alexcooper.com
# ----
# -1
# -1
# foreclosure   real property 3014 22nd st., se washington, dc 20020
# no auction location
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/9.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/listings/94141/00025051.html
# 4910-04-11 00:00:00
# 11:06 AM
# 2005-02-08 00:00:00
# no auction location
# Alex Cooper Auctioneers, http://www.alexcooper.com
# ----
# -1
# -1
# judicial   real property 5002 11th st., ne washington, dc 20017
# no auction location
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/10.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/listings/95192/00026169.html
# 4910-04-11 00:00:00
# 12:04 PM
# 2003-11-14 00:00:00
# no auction location
# Alex Cooper Auctioneers, http://www.alexcooper.com
# ----
# -1
# -1
# judicial   real property 719 adrian st., se washington, dc 20019
# no auction location
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/10.html
# http://classified.washingtontimes.com/category/357/Foreclosure-Sales-DC/listings/95198/00026170.html
# 4910-04-11 00:00:00
# 12:06 PM
# 2007-09-22 00:00:00
# no auction location
# Alex Cooper Auctioneers, http://www.alexcooper.com
# ----
# 98223
# 20000
# 3121 n pershing drive, arlington, va 22201
# 1425 N Courthouse Rd #2400, Arlington, VA 22201
# http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty.html
# http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty/listings/94472/00025540.html
# 2019-04-29 00:00:00
# 1:30 PM
# 1425-04-11 00:00:00
# 1425 N Courthouse Rd #2400, Arlington, VA 22201
# Samuel I. White, PC, Law Firm, http://www.siwpc.com
# ----
# -1
# 20000
# 935 s wakefield street, arlington, va 22204
# 1425 N Courthouse Rd #2400, Arlington, VA 22201
# http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty.html
# http://classified.washingtontimes.com/category/355/Foreclosure-Sales-ARL-Cty/listings/94241/00025206.html
# 2019-04-01 00:00:00
# 10:00 AM
# 1425-04-11 00:00:00
# 1425 N Courthouse Rd #2400, Arlington, VA 22201
# Samuel I. White, PC, Law Firm, http://www.siwpc.com
# ----

# %%
_tmp = collection.find_one()["_id"]

# %%
# gkey = 'AIzaSyDJVHUu96plcDqAI2Bt64siywZOs7pWZ6w'

# for x in collection:
#     target_location = collection.find_one()["property_address"]

#     target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
#                                'address={0}&key={1}').format(target_location, gkey)

#     geo_data = requests.get(target_url).json()

#     lat = geo_data["results"][0]["geometry"]["location"]["lat"]
#     lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# # Print the latitude and longitude
# print('''
#     City: {0}
#     Latitude: {1}
#     Longitude: {2}
#     '''.format(target_location, lat, lng))

# %%
# for address in collection.find_one(["property_address"]):
#      latlng = get_latlng_scrap(collection)

# %%
api = zillow.ValuationApi()

# %%
db_address = collection.find_one()["property_address"]

def get_zip(db_address):
    zip_code = re.search("\d{5}",db_address)[0]
    return zip_code

# %%
db_address
# Out:
# '4106 north randolph street, arlington, va 22207'

# %%
zillow_api_key = "X1-ZWz1gx8me6fbbf_a57uf"

zip_code = get_zip(db_address)
place = api.GetDeepSearchResults(zillow_api_key, db_address, zip_code)

# %%
collection.find_one()["property_address"]
# Out:
# '4106 north randolph street, arlington, va 22207'

# %%
for item in collection.find():
    db_address = item["property_address"] 
    zillow_api_key = "X1-ZWz1gx8me6fbbf_a57uf"
    
    try:
        zip_code = get_zip(db_address)
        place = api.GetDeepSearchResults(zillow_api_key, db_address, zip_code) 
    except:
        pass
    
    zestimate = place.zestimate.amount,
    zstreet_address = place.full_address.street,
    zstate = place.full_address.state,
    zcity = place.full_address.city,
    zzip = place.full_address.zipcode,
    lat = place.full_address.latitude,
    lgn = place.full_address.longitude,
    bedrooms = place.extended_data.bedrooms,
    bathrooms = place.extended_data.bathrooms,
    lot_size = place.extended_data.lot_size_sqft,
    zpid = place.zpid,
    region_name = place.local_realestate.region_name
    
    
    print(place.zestimate.amount)
    print(place.full_address.street)
    print(place.full_address.state)
    print(place.full_address.city)
    print(place.full_address.zipcode)
    print(place.full_address.latitude)
    print(place.full_address.longitude)
    print(place.extended_data.bedrooms)
    print(place.extended_data.bathrooms)
    print(place.extended_data.lot_size_sqft)
    print(place.zpid)
    print(place.local_realestate.region_name)
    print("-------------")
  
    post2 = {
        "unique_id": item['_id'],
        "zestimate": place.zestimate.amount,
        "zstreet_address": place.full_address.street,
        "zstate": place.full_address.state,
        "zcity": place.full_address.city,
        "zzip": place.full_address.zipcode,
        "lat": place.full_address.latitude,
        "lgn": place.full_address.longitude,
        "bedrooms": place.extended_data.bedrooms,
        "bathrooms": place.extended_data.bathrooms,
        "lot_size": place.extended_data.lot_size_sqft,
        "zpid": place.zpid,
        "region_name": place.local_realestate.region_name,
            }
    
    collection2.insert_one(post2)
# Out:
# 1236107
# 4106 N Randolph St
# VA
# Arlington
# 22207
# 38.928482
# -77.121981
# 4
# 3.0
# 11890
# 12059518
# Arlington
# -------------
# 163859
# 31 Canterbury Sq APT 201
# VA
# Alexandria
# 22304
# 38.813867
# -77.121951
# None
# 1.0
# None
# 192147210
# Landmark-Van Dom
# -------------
# 209401
# 3314 S 28th St APT 203
# VA
# Alexandria
# 22302
# 38.838223
# -77.106478
# None
# 1.0
# None
# 192149558
# Alexandria West
# -------------
# 321055
# 3407 Valley Dr # 701
# VA
# Alexandria
# 22302
# 38.836452
# -77.07937
# None
# 1.0
# None
# 192143023
# North Ridge-Rosemont
# -------------
# 975985
# 1773 Potomac Greens Dr
# VA
# Alexandria
# 22314
# 38.828766
# -77.045339
# None
# 2.5
# 1602
# 192157428
# Potomac Yard-Potomac Greens
# -------------
# 264401
# 203 Yoakum Pkwy APT 1707
# VA
# Alexandria
# 22304
# 38.812383
# -77.139957
# None
# 2.0
# None
# 192138567
# Landmark-Van Dom
# -------------
# 264401
# 203 Yoakum Pkwy APT 1707
# VA
# Alexandria
# 22304
# 38.812383
# -77.139957
# None
# 2.0
# None
# 192138567
# Landmark-Van Dom
# -------------
# 327169
# 3408 Gunston Rd # 735
# VA
# Alexandria
# 22302
# 38.836441
# -77.077834
# None
# 1.0
# None
# 192143024
# North Ridge-Rosemont
# -------------
# 271382
# 402 Bashford Ln APT 202
# VA
# Alexandria
# 22314
# 38.817837
# -77.041377
# 1
# 1.0
# None
# 192145261
# Old Town North
# -------------
# 271382
# 402 Bashford Ln APT 202
# VA
# Alexandria
# 22314
# 38.817837
# -77.041377
# 1
# 1.0
# None
# 192145261
# Old Town North
# -------------
# 274835
# 114 Catoctin Cir SW
# VA
# Leesburg
# 20175
# 39.108764
# -77.570362
# 3
# 3.0
# 2178
# 12411673
# Leesburg
# -------------
# 363282
# 3 Berkeley Ct
# VA
# Sterling
# 20165
# 39.043964
# -77.411509
# 3
# 2.5
# 1742
# 12386539
# Sterling
# -------------
# 363282
# 3 Berkeley Ct
# VA
# Sterling
# 20165
# 39.043964
# -77.411509
# 3
# 2.5
# 1742
# 12386539
# Sterling
# -------------
# 915562
# 1825 Potomac Greens Dr
# VA
# Alexandria
# 22314
# 38.829816
# -77.045387
# None
# 3.5
# 1280
# 192157449
# Potomac Yard-Potomac Greens
# -------------
# 569562
# 7514 Rolling Rd
# VA
# Springfield
# 22153
# 38.753043
# -77.216813
# 3
# 3.0
# 14784
# 51940122
# Springfield
# -------------
# 569562
# 7514 Rolling Rd
# VA
# Springfield
# 22153
# 38.753043
# -77.216813
# 3
# 3.0
# 14784
# 51940122
# Springfield
# -------------
# 569562
# 7514 Rolling Rd
# VA
# Springfield
# 22153
# 38.753043
# -77.216813
# 3
# 3.0
# 14784
# 51940122
# Springfield
# -------------
# 565770
# 3507 Tyler St
# VA
# Falls Church
# 22041
# 38.848719
# -77.138576
# 3
# 3.0
# 16091
# 51849756
# Falls Church
# -------------
# 565770
# 3507 Tyler St
# VA
# Falls Church
# 22041
# 38.848719
# -77.138576
# 3
# 3.0
# 16091
# 51849756
# Falls Church
# -------------
# 338027
# 8772 Dunstable Loop
# VA
# Bristow
# 20136
# 38.766855
# -77.563528
# 3
# 3.0
# 1306
# 52003853
# Bristow
# -------------
# 53259
# 15612-1000 Thousand
# PA
# Alverton
# 15612
# 40.141
# -79.5868
# 0
# None
# 6664
# 186774496
# East Huntingdon
# -------------
# 600703
# 8318 Shimmering Rock Rd
# VA
# Gainesville
# 20155
# 38.771504
# -77.60472
# 4
# 4.5
# 15376
# 69218725
# Gainesville
# -------------
# 1232423
# 1266 Cobble Pond Way
# VA
# Vienna
# 22182
# 38.972299
# -77.311371
# 4
# 5.5
# 25000
# 51711926
# Vienna
# -------------
# 439926
# 9331 Cougar Ct
# VA
# Manassas Park
# 20111
# 38.764054
# -77.421589
# 4
# 3.5
# 7579
# 55737586
# Manassas Park
# -------------
# 439926
# 9331 Cougar Ct
# VA
# Manassas Park
# 20111
# 38.764054
# -77.421589
# 4
# 3.5
# 7579
# 55737586
# Manassas Park
# -------------
# 327767
# 2236 Coppersmith Sq
# VA
# Reston
# 20191
# 38.937537
# -77.353489
# 3
# 1.5
# 1306
# 51737956
# South Lakes Dr - Soapstone Dr
# -------------
# 327767
# 2236 Coppersmith Sq
# VA
# Reston
# 20191
# 38.937537
# -77.353489
# 3
# 1.5
# 1306
# 51737956
# South Lakes Dr - Soapstone Dr
# -------------
# 324593
# 1413 D St
# VA
# Woodbridge
# 22191
# 38.657906
# -77.257305
# 3
# 3.0
# 9583
# 12466879
# Marumsco Village
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 259494
# 1813 Old Post Ter
# VA
# Woodbridge
# 22191
# 38.622122
# -77.271411
# 4
# 4.0
# 1481
# 12476054
# Rippon Landing
# -------------
# 1520106
# 1610 Fielding Lewis Way
# VA
# Mclean
# 22101
# 38.926514
# -77.144938
# 4
# 4.5
# 19400
# 51759087
# McLean
# -------------
# 491564
# 3222 Norfolk Ln
# VA
# Falls Church
# 22042
# 38.860496
# -77.200244
# None
# 2.0
# 10319
# 51843398
# Falls Church
# -------------
# 491564
# 3222 Norfolk Ln
# VA
# Falls Church
# 22042
# 38.860496
# -77.200244
# None
# 2.0
# 10319
# 51843398
# Falls Church
# -------------
# 740521
# 9505 Yawl Ct
# VA
# Burke
# 22015
# 38.757232
# -77.27592
# 4
# 5.0
# 12802
# 51933423
# Burke
# -------------
# 581729
# 1312 Yellow Tavern Ct
# VA
# Herndon
# 20170
# 38.999905
# -77.37218
# 4
# 3.5
# 12372
# 51705408
# Herndon
# -------------
# 688546
# 9209 Briary Ln
# VA
# Fairfax
# 22031
# 38.840413
# -77.263283
# 4
# 3.0
# 10890
# 51838541
# Mantua
# -------------
# 688546
# 9209 Briary Ln
# VA
# Fairfax
# 22031
# 38.840413
# -77.263283
# 4
# 3.0
# 10890
# 51838541
# Mantua
# -------------
# 631485
# 3510 Sharon Chapel Rd
# VA
# Alexandria
# 22310
# 38.790339
# -77.093094
# 3
# 3.0
# 22651
# 51923061
# Rose Hill
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 447251
# 6722 Quander Rd
# VA
# Alexandria
# 22307
# 38.771035
# -77.068851
# None
# 1.0
# 12196
# 51956811
# Groveton
# -------------
# 775815
# 3121 N Pershing Dr
# VA
# Arlington
# 22201
# 38.878802
# -77.095563
# 2
# 1.0
# 7840
# 12087122
# Lyon Park
# -------------
# 773424
# 935 S Wakefield St
# VA
# Arlington
# 22204
# 38.858183
# -77.106546
# 2
# 3.5
# 6098
# 12092043
# Barcroft
# -------------
# 197733
# 903 S Frederick St APT 7
# VA
# Arlington
# 22204
# 38.854663
# -77.113372
# 2
# 1.0
# None
# 12095481
# Columbia Forest
# -------------
# 1438894
# McLean
# -------------
# 741418
# 6609 Castle Knoll Dr
# VA
# Clifton
# 20124
# 38.793575
# -77.380472
# 4
# 2.5
# 115586
# 51889791
# Clifton
# -------------
# 401275
# 6124 Hillview Ave
# VA
# Alexandria
# 22310
# 38.783488
# -77.098217
# 3
# 1.0
# 10890
# 51923535
# Groveton
# -------------
# None
# 1822 Fonthill Ct UNIT 22
# VA
# McLean
# 22102
# 38.915407
# -77.211751
# None
# None
# None
# 2084960748
# McLean
# -------------
# 421342
# 2811 Farmington Dr
# VA
# Alexandria
# 22303
# 38.792626
# -77.080621
# 2
# 1.0
# 4562
# 51924441
# Groveton
# -------------
# 686485
# 3898 Plum Run Ct
# VA
# Fairfax
# 22033
# 38.885861
# -77.406804
# 4
# 3.5
# 17353
# 51790110
# Fairfax
# -------------
# 686485
# 3898 Plum Run Ct
# VA
# Fairfax
# 22033
# 38.885861
# -77.406804
# 4
# 3.5
# 17353
# 51790110
# Fairfax
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 429924
# 6039 Liberty Bell Ct
# VA
# Burke
# 22015
# 38.78701
# -77.263082
# 3
# 2.0
# 2613
# 51903894
# Burke
# -------------
# 775815
# 3121 N Pershing Dr
# VA
# Arlington
# 22201
# 38.878802
# -77.095563
# 2
# 1.0
# 7840
# 12087122
# Lyon Park
# -------------
# 773424
# 935 S Wakefield St
# VA
# Arlington
# 22204
# 38.858183
# -77.106546
# 2
# 3.5
# 6098
# 12092043
# Barcroft
# -------------

# %%
gkey = 'AIzaSyDJVHUu96plcDqAI2Bt64siywZOs7pWZ6w'


  
target_location = collection2.find_one()["zstreet_address"]

target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
                           'address={0}&key={1}').format(target_location, gkey)

geo_data = requests.get(target_url).json()

lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_location, lat, lng))
# Out:
#     City: 4106 N Randolph St
#     Latitude: 38.9284956
#     Longitude: -77.12197710000001

# %%
df = pd.DataFrame(list(collection.find()))
df.tail(20)
# Out:
#                           _id  \
# 687  5cafc6f4737ae154e8921f27
# 688  5cafc6f8737ae154e8921f28
# 689  5cafc6fc737ae154e8921f29
# 690  5cafc6ff737ae154e8921f2a
# 691  5cafc703737ae154e8921f2b
# 692  5cafc706737ae154e8921f2c
# 693  5cafc70a737ae154e8921f2d
# 694  5cafc70d737ae154e8921f2e
# 695  5cafc711737ae154e8921f2f
# 696  5cafc714737ae154e8921f30
# 697  5cafc718737ae154e8921f31
# 698  5cafc71b737ae154e8921f32
# 699  5cafc71f737ae154e8921f33
# 700  5cafc722737ae154e8921f34
# 701  5cafc726737ae154e8921f35
# 702  5cafc729737ae154e8921f36
# 703  5cafc72d737ae154e8921f37
# 704  5cafc730737ae154e8921f38
# 705  5cafc734737ae154e8921f39
# 706  5cafc737737ae154e8921f3a
#
#                                      auction_location auction_time  \
# 687                               no auction location   10:34 a.m.
# 688                               no auction location     12:16 PM
# 689                               no auction location     11:02 AM
# 690  5335 Wisconsin Ave NW #440, Washington, DC 20015     11:00 am
# 691                               no auction location     12:12 PM
# 692                               no auction location     11:51 AM
# 693                               no auction location     11:00 AM
# 694  5335 Wisconsin Ave NW #440, Washington, DC 20015     11:00 AM
# 695                               no auction location     12:14 PM
# 696  5335 Wisconsin Ave NW #440, Washington, DC 20015     11:00 AM
# 694  http://classified.washingtontimes.com/category...            308800
# 695  http://classified.washingtontimes.com/category...                -1
# 696  http://classified.washingtontimes.com/category...            378000
# 697  http://classified.washingtontimes.com/category...                -1
# 698  http://classified.washingtontimes.com/category...                -1
# 699  http://classified.washingtontimes.com/category...            115114
# 700  http://classified.washingtontimes.com/category...                -1
# 701  http://classified.washingtontimes.com/category...                -1
# 702  http://classified.washingtontimes.com/category...                -1
# 703  http://classified.washingtontimes.com/category...                -1
# 704  http://classified.washingtontimes.com/category...                -1
# 705  http://classified.washingtontimes.com/category...             98223
# 706  http://classified.washingtontimes.com/category...                -1
#
#           principal_date                                   property_address  \
# 687  1976-04-11 00:00:00                                         no address
# 688  2006-05-22 00:00:00  judicial   real property 1317 w st., se washin...
# 689  2014-01-14 00:00:00  foreclosure   real property 1925 capitol ave.,...
# 690  2006-08-11 00:00:00  judicial   real property 2200 prout street se,...
# 691  2007-11-30 00:00:00  judicial   real property 824 hilltop terr., se...
# 692  2007-05-04 00:00:00  foreclosure   real property 2311 33rd st., se ...
# 693  2004-11-11 00:00:00  foreclosure   real property 4633 greene pl., n...
# 694  2013-03-13 00:00:00  foreclosure   improved real property 3257 stan...
# 695  2006-10-13 00:00:00  judicial   real property 3105 georgia ave., nw...
# 696  2005-04-22 00:00:00  foreclosure   improved real property 11 girard...
# 697  2008-05-16 00:00:00  foreclosure   real property 1139 chaplin st., ...
# 698  2007-10-03 00:00:00  judicial   real property 4004 beecher st., nw ...
# 699  0124-04-11 00:00:00                                         no address
# 700  2005-10-06 00:00:00  foreclosure   real property 4312 g st., se was...
# 701  2006-11-14 00:00:00  foreclosure   real property 5111 13th st., nw ...
# 702  2005-02-08 00:00:00  foreclosure   real property 3014 22nd st., se ...
# 703  2003-11-14 00:00:00  judicial   real property 5002 11th st., ne was...
# 704  2007-09-22 00:00:00  judicial   real property 719 adrian st., se wa...
# 705  1425-04-11 00:00:00         3121 n pershing drive, arlington, va 22201
# 706  1425-04-11 00:00:00        935 s wakefield street, arlington, va 22204
#
#      url
# 687  NaN
# 688  NaN
# 689  NaN
# 690  NaN
# 691  NaN
# 692  NaN
# 693  NaN
# 694  NaN
# 695  NaN
# 696  NaN
# 697  NaN
# 698  NaN
# 699  NaN
# 700  NaN
# 701  NaN
# 702  NaN
# 703  NaN
# 704  NaN
# 705  NaN
# 706  NaN

# %%
df2 = pd.DataFrame(list(collection2.find()))
df2.tail()
# Out:
#                            _id bathrooms bedrooms        lat         lgn  \
# 2028  5cafc7fb737ae154e89221f9       2.0        3   38.78701  -77.263082
# 2029  5cafc7fb737ae154e89221fa       2.0        3   38.78701  -77.263082
# 2030  5cafc7fc737ae154e89221fb       2.0        3   38.78701  -77.263082
# 2031  5cafc7fc737ae154e89221fc       1.0        2  38.878802  -77.095563
# 2032  5cafc7fc737ae154e89221fd       3.5        2  38.858183  -77.106546
#
#      lot_size region_name                 unique_id      zcity  zestimate  \
# 2028     2613       Burke  5cafc729737ae154e8921f36      Burke   429924.0
# 2029     2613       Burke  5cafc72d737ae154e8921f37      Burke   429924.0
# 2030     2613       Burke  5cafc730737ae154e8921f38      Burke   429924.0
# 2031     7840   Lyon Park  5cafc734737ae154e8921f39  Arlington   775815.0
# 2032     6098    Barcroft  5cafc737737ae154e8921f3a  Arlington   773424.0
#
#           zpid zstate       zstreet_address   zzip
# 2028  51903894     VA  6039 Liberty Bell Ct  22015
# 2029  51903894     VA  6039 Liberty Bell Ct  22015
# 2030  51903894     VA  6039 Liberty Bell Ct  22015
# 2031  12087122     VA    3121 N Pershing Dr  22201
# 2032  12092043     VA    935 S Wakefield St  22204

# %%
df3 = df.merge(df2, left_on="_id", right_on="unique_id", how="inner")
df3.tail()
# Out:
#                          _id_x  \
# 2016  5cafc729737ae154e8921f36
# 2017  5cafc72d737ae154e8921f37
# 2018  5cafc730737ae154e8921f38
# 2019  5cafc734737ae154e8921f39
# 2020  5cafc737737ae154e8921f3a
#
#                                      auction_location auction_time  \
# 2016                              no auction location     11:06 AM
# 2017                              no auction location     12:04 PM
# 2018                              no auction location     12:06 PM
# 2019  1425 N Courthouse Rd #2400, Arlington, VA 22201      1:30 PM
# 2020  1425 N Courthouse Rd #2400, Arlington, VA 22201     10:00 AM
#
#                                                city_url      date_of_auction  \
# 2016  http://classified.washingtontimes.com/category...  4910-04-11 00:00:00
# 2017  http://classified.washingtontimes.com/category...  4910-04-11 00:00:00
# 2018  http://classified.washingtontimes.com/category...  4910-04-11 00:00:00
# 2019  http://classified.washingtontimes.com/category...  2019-04-29 00:00:00
# 2020  http://classified.washingtontimes.com/category...  2019-04-01 00:00:00
#
#             date_of_scraping  deposit  \
# 2016 2019-04-11 23:00:57.909     -1.0
# 2017 2019-04-11 23:01:01.379     -1.0
# 2018 2019-04-11 23:01:04.745     -1.0
# 2019 2019-04-11 23:01:08.203  20000.0
# 2020 2019-04-11 23:01:11.489  20000.0
#
#                                                law_firm lawfirm  \
# 2016  Alex Cooper Auctioneers, http://www.alexcooper...     NaN
# 2017  Alex Cooper Auctioneers, http://www.alexcooper...     NaN
# 2018  Alex Cooper Auctioneers, http://www.alexcooper...     NaN
# 2019  Samuel I. White, PC, Law Firm, http://www.siwp...     NaN
# 2020  Samuel I. White, PC, Law Firm, http://www.siwp...     NaN
#
#                                             listing_url  ...           lgn  \
# 2016  http://classified.washingtontimes.com/category...  ...    -77.263082
# 2017  http://classified.washingtontimes.com/category...  ...    -77.263082
# 2018  http://classified.washingtontimes.com/category...  ...    -77.263082
# 2019  http://classified.washingtontimes.com/category...  ...    -77.095563
# 2020  http://classified.washingtontimes.com/category...  ...    -77.106546
#
#      lot_size region_name                 unique_id      zcity zestimate  \
# 2016     2613       Burke  5cafc729737ae154e8921f36      Burke  429924.0
# 2017     2613       Burke  5cafc72d737ae154e8921f37      Burke  429924.0
# 2018     2613       Burke  5cafc730737ae154e8921f38      Burke  429924.0
# 2019     7840   Lyon Park  5cafc734737ae154e8921f39  Arlington  775815.0
# 2020     6098    Barcroft  5cafc737737ae154e8921f3a  Arlington  773424.0
#
#           zpid zstate       zstreet_address   zzip
# 2016  51903894     VA  6039 Liberty Bell Ct  22015
# 2017  51903894     VA  6039 Liberty Bell Ct  22015
# 2018  51903894     VA  6039 Liberty Bell Ct  22015
# 2019  12087122     VA    3121 N Pershing Dr  22201
# 2020  12092043     VA    935 S Wakefield St  22204
#
# [5 rows x 28 columns]

# %%
# !pip install dash==0.39.0
# !pip install dash-daq==0.1.0
# Out:
# Requirement already satisfied: dash==0.39.0 in c:\programdata\anaconda3\lib\site-packages (0.39.0)
# Requirement already satisfied: flask-compress in c:\programdata\anaconda3\lib\site-packages (from dash==0.39.0) (1.4.0)
# Requirement already satisfied: Flask>=0.12 in c:\programdata\anaconda3\lib\site-packages (from dash==0.39.0) (1.0.2)
# Requirement already satisfied: dash-core-components==0.44.0 in c:\programdata\anaconda3\lib\site-packages (from dash==0.39.0) (0.44.0)
# Requirement already satisfied: dash-html-components==0.14.0 in c:\programdata\anaconda3\lib\site-packages (from dash==0.39.0) (0.14.0)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\lib\site-packages (from dash==0.39.0) (3.7.1)
# Requirement already satisfied: dash-table==3.6.0 in c:\programdata\anaconda3\lib\site-packages (from dash==0.39.0) (3.6.0)
# Requirement already satisfied: dash-renderer==0.20.0 in c:\programdata\anaconda3\lib\site-packages (from dash==0.39.0) (0.20.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.12->dash==0.39.0) (0.24)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.12->dash==0.39.0) (6.7)
# Requirement already satisfied: Jinja2>=2.10 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.12->dash==0.39.0) (2.10)
# Requirement already satisfied: Werkzeug>=0.14 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.12->dash==0.39.0) (0.14.1)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from plotly->dash==0.39.0) (2018.5)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from plotly->dash==0.39.0) (2.19.1)
# Requirement already satisfied: retrying>=1.3.3 in c:\programdata\anaconda3\lib\site-packages (from plotly->dash==0.39.0) (1.3.3)
# Requirement already satisfied: nbformat>=4.2 in c:\programdata\anaconda3\lib\site-packages (from plotly->dash==0.39.0) (4.4.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from plotly->dash==0.39.0) (1.11.0)
# Requirement already satisfied: decorator>=4.0.6 in c:\programdata\anaconda3\lib\site-packages (from plotly->dash==0.39.0) (4.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10->Flask>=0.12->dash==0.39.0) (1.0)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->plotly->dash==0.39.0) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->plotly->dash==0.39.0) (2018.11.29)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->plotly->dash==0.39.0) (1.23)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->plotly->dash==0.39.0) (3.0.4)
# Requirement already satisfied: ipython-genutils in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->dash==0.39.0) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->dash==0.39.0) (2.6.0)
# Requirement already satisfied: traitlets>=4.1 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->dash==0.39.0) (4.3.2)
# Requirement already satisfied: jupyter-core in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.2->plotly->dash==0.39.0) (4.4.0)
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: dash-daq==0.1.0 in c:\programdata\anaconda3\lib\site-packages (0.1.0)
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
df3.to_csv("LatandLng.csv")

# %%
df3.columns
# Out:
# Index(['_id_x', 'auction_location', 'auction_time', 'city_url',
#        'date_of_auction', 'date_of_scraping', 'deposit', 'law_firm', 'lawfirm',
#        'listing_url', 'principal_amount', 'principal_date', 'property_address',
#        'url', '_id_y', 'bathrooms', 'bedrooms', 'lat', 'lgn', 'lot_size',
#        'region_name', 'unique_id', 'zcity', 'zestimate', 'zpid', 'zstate',
#        'zstreet_address', 'zzip'],
#       dtype='object')

# %%
df3[["principal_amount", "principal_date"]].tail(20)
# Out:
#       principal_amount       principal_date
# 2001                -1  1976-04-11 00:00:00
# 2002                -1  2006-05-22 00:00:00
# 2003                -1  2014-01-14 00:00:00
# 2004                -1  2006-08-11 00:00:00
# 2005                -1  2007-11-30 00:00:00
# 2006                -1  2007-05-04 00:00:00
# 2007             85000  2004-11-11 00:00:00
# 2008            308800  2013-03-13 00:00:00
# 2009                -1  2006-10-13 00:00:00
# 2010            378000  2005-04-22 00:00:00
# 2011                -1  2008-05-16 00:00:00
# 2012                -1  2007-10-03 00:00:00
# 2013            115114  0124-04-11 00:00:00
# 2014                -1  2005-10-06 00:00:00
# 2015                -1  2006-11-14 00:00:00
# 2016                -1  2005-02-08 00:00:00
# 2017                -1  2003-11-14 00:00:00
# 2018                -1  2007-09-22 00:00:00
# 2019             98223  1425-04-11 00:00:00
# 2020                -1  1425-04-11 00:00:00

# %%
delta = datetime.datetime.now() - df3["principal_date"].iloc[1312]

# %%
days = delta.days
days
# Out:
# 13379

# %%
def day_from_now(principal_date):
    try:
        delta = datetime.datetime.now() - principal_date
        return delta.days
    except:
        return -1

# %%
df3["days_from_principal_date"] = df3["principal_date"].apply(day_from_now)

# %%
df3["estimated_principal"] =  (1 - df3["days_from_principal_date"]/(365*30))*df3["principal_amount"]

# %%
df3[["estimated_principal", "principal_amount", "days_from_principal_date"]].astype(int)
# Out:
#       estimated_principal  principal_amount  days_from_principal_date
# 0                  675061            675000                        -1
# 1                  675061            675000                        -1
# 2                  675061            675000                        -1
# 3                  675061            675000                        -1
# 4                  675061            675000                        -1
# 5                  151223            151210                        -1
# 6                  151223            151210                        -1
# 7                  151223            151210                        -1
# 8                  151223            151210                        -1
# 9                  151223            151210                        -1
# 10                     -1                -1                        -1
# 11                     -1                -1                        -1
# 12                     -1                -1                        -1
# 13                     -1                -1                        -1
# 14                     -1                -1                        -1
# 15                 215018            214999                        -1
# 16                 215018            214999                        -1
# 17                 215018            214999                        -1
# 18                 215018            214999                        -1
# 19                 215018            214999                        -1
# 20                  82507             82500                        -1
# 21                  82507             82500                        -1
# 22                  82507             82500                        -1
# 23                  82507             82500                        -1
# 24                  82507             82500                        -1
# 25                 262523            262500                        -1
# 26                 262523            262500                        -1
# 27                 262523            262500                        -1
# 28                 262523            262500                        -1
# 29                 262523            262500                        -1
# ...                   ...               ...                       ...
# 1991                    0                -1                      6243
# 1992               231189            480000                      5676
# 1993               157237            250000                      4063
# 1994               569352            648000                      1329
# 1995               191560            315000                      4291
# 1996               517122            578396                      1160
# 1997                    0                -1                      3313
# 1998               182998            303750                      4353
# 1999                   62                -1                    697613
# 2000                38180             65000                      4518
# 2001                    0                -1                     15705
# 2002                    0                -1                      4707
# 2003                    0                -1                      1913
# 2004                    0                -1                      4626
# 2005                    0                -1                      4150
# 2006                    0                -1                      4360
# 2007                44137             85000                      5264
# 2008               246193            308800                      2220
# 2009                    0                -1                      4563
# 2010               201876            378000                      5102
# 2011                    0                -1                      3982
# 2012                    0                -1                      4208
# 2013             -7161078            115114                    692134
# 2014                    0                -1                      4935
# 2015                    0                -1                      4531
# 2016                    0                -1                      5175
# 2017                    0                -1                      5627
# 2018                    0                -1                      4219
# 2019             -1847884             98223                    216954
# 2020                   18                -1                    216954
#
# [2021 rows x 3 columns]

# %%
df3["estimated_equity"] = (df3["estimated_principal"]-df3["zestimate"]).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-27a118ca540d> in <module>()
# ----> 1 df3["estimated_equity"] = (df3["estimated_principal"]-df3["zestimate"]).astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5001                                          **kwargs)
#    5002             return self._constructor(new_data).__finalize__(self)
#    5003
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, **kwargs)
#    3712
#    3713     def astype(self, dtype, **kwargs):
# -> 3714         return self.apply('astype', dtype=dtype, **kwargs)
#    3715
#    3716     def convert(self, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     573     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     574         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 575                             **kwargs)
#     576
#     577     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     662
#     663                 # _astype_nansafe works fine with 1-d only
# --> 664                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     665                 values = values.reshape(self.shape)
#     666
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy)
#     700
#     701         if not np.isfinite(arr).all():
# --> 702             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     703                              'integer')
#     704
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
df3.columns

# %%
#db.dropDatabase(collection)
#db.dropDatabase(collection2)
